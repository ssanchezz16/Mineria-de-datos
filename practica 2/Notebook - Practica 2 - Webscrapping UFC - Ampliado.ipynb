# %% [markdown]
# <table>
#     <tr>
#       <td>Minería de datos y Paradigma BigData (<b>MIN</b>) - Facultad de Informática - UCM
#       </td>
#       <td>
#       <img src="https://biblioteca.ucm.es/data/cont/media/www/pag-88746//escudo.jpg"  width=50/>
#       </td>
#      </tr>
# </table>
#
#
#
#
# ### Práctica 1 - Web scrapping de Ultimate Fighting Championship
# Pablo C. Cañizares
#
# Arturo Gómez Izquierdo y Sara Alexandra Sánchez Del Río

# %% [markdown]
# ### Se nos encarga preparar un dataset de luchadores de la compañía para futuras decisiones estratégicas
# Entre estas decisiones radican posibles `matchmaking` de combates, herramientas para ojeadores, potenciación de carreras o incluso `¡despidos!`
#
# Empezamos por acceder a la página de estadísicas de la reputada compañias de artes marciales mixtas UFC `ufcstats.com`. Específicamente, vamos a analizar inicialmente al vigente campeón del peso pluma el hispano-georgiano `Ilia "El matador" Topuria`. Para ello, accedemos al enlace `http://ufcstats.com/fighter-details/54f64b5e283b0ce7`

# %%
# (Solo ejecutar si hay problemas con la version de numpy)
#import sys
#!{sys.executable} -m pip uninstall -y pyarrow numexpr bottleneck streamlit
# Out:
# Found existing installation: pyarrow 16.1.0
# Uninstalling pyarrow-16.1.0:
#   Successfully uninstalled pyarrow-16.1.0
# Found existing installation: numexpr 2.8.7
# Uninstalling numexpr-2.8.7:
#   Successfully uninstalled numexpr-2.8.7
# Found existing installation: Bottleneck 1.3.7
# Uninstalling Bottleneck-1.3.7:
#   Successfully uninstalled Bottleneck-1.3.7
# Found existing installation: streamlit 1.37.1
# Uninstalling streamlit-1.37.1:
#   Successfully uninstalled streamlit-1.37.1

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests


def loadPage(urlIn):
    page = requests.get(urlIn)
    soup = BeautifulSoup(page.text, 'html.parser')  # le pasamos el texto en HTML para que lo analice
    return soup

url = "http://ufcstats.com/fighter-details/54f64b5e283b0ce7"
soup = loadPage(url) 
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html class="no-js ie8 lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js"> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>
#     Stats | UFC
#   </title>
# <meta content="" name="description"/>
# <meta content="" name="viewport"/>
# <link href="/blocks/main.css?ver=861173" rel="stylesheet"/>
# <script src="/js/vendor/modernizr-2.6.2.min.js"></script>
# <script>
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#     m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#     ga('create', 'UA-2855164-1', 'auto');
#     ga('send', 'pageview');
#   </script>
# </head>
# <body class="b-page" data-link="home">
# <header class="b-head">
# <div class="b-head__nav-bar">
# <div class="l-page__container">
# <a class="b-head__logo" href="/">
# <img alt="" src="http://1e49bc5171d173577ecd-1323f4090557a33db01577564f60846c.r80.cf1.rackcdn.com/ufc-stats-logo.png"/>
# </a>
# <menu class="b-head__menu">
# <li class="b-head__item">
# <a class="b-head__menu-link" href="/statistics/events/">
#               EVENTS &amp; FIGHTS
#             </a>
# </li>
# <li class="b-head__item b-head__item_state_current">
# <a class="b-head__menu-link" href="/statistics/fighters">
#               FIGHTERS
#             </a>
# </li>
# <li class="b-head__item">
# <a class="b-head__menu-link" href="http://statleaders.ufc.com" target="_blank">
#               STAT LEADERS
#             </a>
# </li>
# </menu>
# </div>
# </div>
# <div class="b-head__sub-nav">
# </div>
# </header>
# <section class="b-statistics__section_details">
# <script type="text/javascript">
#     function doNav(url) {
#         document.location.href = url;
#
#     }
# </script>
# <div class="l-page__container">
# <h2 class="b-content__title">
# <span class="b-content__title-highlight">
#                 Ilia Topuria
#
#             </span>
# <span class="b-content__title-record">
#                 Record: 17-0-0
#             </span>
# </h2>
# <p class="b-content__Nickname">
#   El Matador
# </p>
# <div class="b-fight-details b-fight-details_margin-top">
# <div class="b-list__info-box b-list__info-box_style_small-width js-guide">
# <ul class="b-list__box-list">
# <li class="b-list__box-list-item b-list__box-list-item_type_block">
# <i class="b-list__box-item-title b-list__box-item-title_type_width">
#         Height:
#       </i>
#       5' 7"
#     </li>
# <li class="b-list__box-list-item b-list__box-list-item_type_block">
# <i class="b-list__box-item-title b-list__box-item-title_type_width">
#         Weight:
#       </i>
#       155 lbs.
#     </li>
# <li class="b-list__box-list-item b-list__box-list-item_type_block">
# <i class="b-list__box-item-title b-list__box-item-title_type_width">
#         Reach:
#       </i>
#       69"
#     </li>
# <li class="b-list__box-list-item b-list__box-list-item_type_block">
# <i class="b-list__box-item-title b-list__box-item-title_type_width">
#         STANCE:
#       </i>
#       Orthodox
#     </li>
# <li class="b-list__box-list-item b-list__box-list-item_type_block">
# <i class="b-list__box-item-title b-list__box-item-title_type_width">
#         DOB:
#       </i>
#
#         Jan 21, 1997
#
#     </li>
# </ul>
# </div>
# <div class="b-list__info-box b-list__info-box_style_middle-width js-guide clearfix">
# <div class="b-list__info-box-left clearfix">
# <div class="b-list__info-box-left">
# <i class="b-list__box-item-title">
#         Career statistics:
#       </i>
# <ul class="b-list__box-list b-list__box-list_margin-top">
# <li class="b-list__box-list-item b-list__box-list-item_type_block">
# <i class="b-list__box-item-title b-list__box-item-title_font_lowercase b-list__box-item-title_type_width">
#             SLpM:
#           </i>
#
#           4.81
#
#         </li>
# <li class="b-list__box-list-item b-list__box-list-item_type_block">
# <i class="b-list__box-item-title b-list__box-item-title_font_lowercase b-list__box-item-title_type_width">
#             Str. Acc.:
#           </i>
#           48%
#         </li>
# <li class="b-list__box-list-item b-list__box-list-item_type_block">
# <i class="b-list__box-item-title b-list__box-item-title_font_lowercase b-list__box-item-title_type_width">
#             SApM:
#           </i>
#           3.83
#         </li>
# <li class="b-list__box-list-item b-list__box-list-item_type_block">
# <i class="b-list__box-item-title b-list__box-item-title_font_lowercase b-list__box-item-title_type_width">
#             Str. Def:
#           </i>
#           64%
#         </li>
# </ul>
# </div>
# <div class="b-list__info-box-right b-list__info-box_style-margin-right">
# <ul class="b-list__box-list b-list__box-list_margin-top">
# <li class="b-list__box-list-item b-list__box-list-item_type_block">
# <i class="b-list__box-item-title b-list__box-item-title_type_width">
# </i>
# </li>
# <li class="b-list__box-list-item b-list__box-list-item_type_block">
# <i class="b-list__box-item-title b-list__box-item-title_font_lowercase b-list__box-item-title_type_width">
#             TD Avg.:
#           </i>
#           1.96
#         </li>
# <li class="b-list__box-list-item b-list__box-list-item_type_block">
# <i class="b-list__box-item-title b-list__box-item-title_font_lowercase b-list__box-item-title_type_width">
#             TD Acc.:
#           </i>
#           61%
#         </li>
# <li class="b-list__box-list-item b-list__box-list-item_type_block">
# <i class="b-list__box-item-title b-list__box-item-title_font_lowercase b-list__box-item-title_type_width">
#             TD Def.:
#           </i>
#           93%
#         </li>
# <li class="b-list__box-list-item b-list__box-list-item_type_block">
# <i class="b-list__box-item-title b-list__box-item-title_font_lowercase b-list__box-item-title_type_width">
#             Sub. Avg.:
#           </i>
#           1.1
#         </li>
# </ul>
# </div>
# </div>
# <div class="b-list__info-box-right b-list__info-box_style_border-left b-list__info-box-right_style_middle-width">
# <p class="b-list__box-content">
# <i class="b-list__box-content_style_strong">
#         SLpM -
#       </i>
#       Significant Strikes Landed per Minute
#     </p>
# <p class="b-list__box-content">
# <i class="b-list__box-content_style_strong">
#         Str. Acc. -
#       </i>
#       Significant Striking Accuracy
#     </p>
# <p class="b-list__box-content">
# <i class="b-list__box-content_style_strong">
#         SApM -
#       </i>
#       Significant Strikes Absorbed per Minute
#     </p>
# <p class="b-list__box-content">
# <i class="b-list__box-content_style_strong">
#         Str. Def. -
#       </i>
#       Significant Strike Defence (the % of opponents strikes that did not land)
#     </p>
# <p class="b-list__box-content">
# <i class="b-list__box-content_style_strong">
#         TD Avg. -
#       </i>
#       Average Takedowns Landed per 15 minutes
#     </p>
# <p class="b-list__box-content">
# <i class="b-list__box-content_style_strong">
#         TD Acc. -
#       </i>
#       Takedown Accuracy
#     </p>
# <p class="b-list__box-content">
# <i class="b-list__box-content_style_strong">
#         TD Def. -
#       </i>
#       Takedown Defense (the % of opponents TD attempts that did not land)
#     </p>
# <p class="b-list__box-content">
# <i class="b-list__box-content_style_strong">
#         Sub. Avg. -
#       </i>
#       Average Submissions Attempted per 15 minutes
#     </p>
# <i class="b-list__box-line"></i>
# </div>
# </div>
# <div class="b-statistics__table-preview">
# <i class="b-statistics__table-preview-item">
#     Click on row to see detailed stats
#   </i>
# </div>
# <table class="b-fight-details__table b-fight-details__table_style_margin-top b-fight-details__table_type_event-details js-fight-table" style="display: table;">
# <thead class="b-fight-details__table-head">
# <tr class="b-fight-details__table-row">
# <th class="b-fight-details__table-col">
#     W/L
#   </th>
# <th class="b-fight-details__table-col l-page_align_left">
#     Fighter
#   </th>
# <th class="b-fight-details__table-col">
#     Kd
#   </th>
# <th class="b-fight-details__table-col">
#     Str
#   </th>
# <th class="b-fight-details__table-col">
#     Td
#   </th>
# <th class="b-fight-details__table-col">
#     Sub
#   </th>
# <th class="b-fight-details__table-col l-page_align_left">
#     Event
#   </th>
# <th class="b-fight-details__table-col l-page_align_left">
#     Method
#   </th>
# <th class="b-fight-details__table-col">
#     Round
#   </th>
# <th class="b-fight-details__table-col">
#     Time
#   </th>
# </tr>
# </thead>
# <tbody class="b-fight-details__table-body">
# <tr class="b-statistics__table-row">
# <td class="b-statistics__table-col_type_clear"></td>
# </tr>
# <tr class="b-fight-details__table-row b-fight-details__table-row__hover js-fight-details-click" data-link="http://ufcstats.com/fight-details/7a64d63e12618ba7" onclick="doNav('http://ufcstats.com/fight-details/7a64d63e12618ba7')">
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
# <a class="b-flag b-flag_style_green" href="http://ufcstats.com/fight-details/7a64d63e12618ba7"><i class="b-flag__inner"><i class="b-flag__text">win<i class="b-flag__corner"></i><i class="b-flag__corner-substrate"></i></i></i></a>
# </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/fighter-details/54f64b5e283b0ce7">
#             Ilia Topuria
#           </a>
# </p>
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/fighter-details/07225ba28ae309b6">
#             Charles Oliveira
#           </a>
# </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#               1
#             </p>
# <p class="b-fight-details__table-text">
#               0
#             </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#               21
#             </p>
# <p class="b-fight-details__table-text">
#               9
#             </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#               0
#             </p>
# <p class="b-fight-details__table-text">
#               0
#             </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#               0
#             </p>
# <p class="b-fight-details__table-text">
#               0
#             </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/event-details/66766984842c13dc">
#             UFC 317: Topuria vs. Oliveira
#           </a>
# </p>
# <p class="b-fight-details__table-text">
# <img alt="" src="http://1e49bc5171d173577ecd-1323f4090557a33db01577564f60846c.r80.cf1.rackcdn.com/belt.png"/>
#
#           Jun. 28, 2025
#         </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
#
#
#
#           KO/TKO
#         <img alt="" src="http://1e49bc5171d173577ecd-1323f4090557a33db01577564f60846c.r80.cf1.rackcdn.com/perf.png" style="padding-bottom:3px;margin-right:2px;"/>
# </p>
# <p class="b-fight-details__table-text">
#           Punch
#         </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#           1
#         </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#           2:27
#         </p>
# </td>
# </tr>
# <tr class="b-fight-details__table-row b-fight-details__table-row__hover js-fight-details-click" data-link="http://ufcstats.com/fight-details/ebf7cea27b83c432" onclick="doNav('http://ufcstats.com/fight-details/ebf7cea27b83c432')">
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
# <a class="b-flag b-flag_style_green" href="http://ufcstats.com/fight-details/ebf7cea27b83c432"><i class="b-flag__inner"><i class="b-flag__text">win<i class="b-flag__corner"></i><i class="b-flag__corner-substrate"></i></i></i></a>
# </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/fighter-details/54f64b5e283b0ce7">
#             Ilia Topuria
#           </a>
# </p>
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/fighter-details/150ff4cc642270b9">
#             Max Holloway
#           </a>
# </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#               1
#             </p>
# <p class="b-fight-details__table-text">
#               0
#             </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#               75
#             </p>
# <p class="b-fight-details__table-text">
#               79
#             </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#               2
#             </p>
# <p class="b-fight-details__table-text">
#               0
#             </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#               0
#             </p>
# <p class="b-fight-details__table-text">
#               0
#             </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/event-details/221b2a3070c7ce3e">
#             UFC 308: Topuria vs. Holloway
#           </a>
# </p>
# <p class="b-fight-details__table-text">
# <img alt="" src="http://1e49bc5171d173577ecd-1323f4090557a33db01577564f60846c.r80.cf1.rackcdn.com/belt.png"/>
#
#           Oct. 26, 2024
#         </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
#
#
#
#           KO/TKO
#         <img alt="" src="http://1e49bc5171d173577ecd-1323f4090557a33db01577564f60846c.r80.cf1.rackcdn.com/perf.png" style="padding-bottom:3px;margin-right:2px;"/>
# </p>
# <p class="b-fight-details__table-text">
#           Punch
#         </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#           3
#         </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#           1:34
#         </p>
# </td>
# </tr>
# <tr class="b-fight-details__table-row b-fight-details__table-row__hover js-fight-details-click" data-link="http://ufcstats.com/fight-details/bec3154a11df3299" onclick="doNav('http://ufcstats.com/fight-details/bec3154a11df3299')">
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
# <a class="b-flag b-flag_style_green" href="http://ufcstats.com/fight-details/bec3154a11df3299"><i class="b-flag__inner"><i class="b-flag__text">win<i class="b-flag__corner"></i><i class="b-flag__corner-substrate"></i></i></i></a>
# </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/fighter-details/54f64b5e283b0ce7">
#             Ilia Topuria
#           </a>
# </p>
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/fighter-details/e1248941344b3288">
#             Alexander Volkanovski
#           </a>
# </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#               1
#             </p>
# <p class="b-fight-details__table-text">
#               0
#             </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#               35
#             </p>
# <p class="b-fight-details__table-text">
#               47
#             </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#               0
#             </p>
# <p class="b-fight-details__table-text">
#               0
#             </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#               0
#             </p>
# <p class="b-fight-details__table-text">
#               0
#             </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/event-details/dab0e6cb8c932162">
#             UFC 298: Volkanovski vs. Topuria
#           </a>
# </p>
# <p class="b-fight-details__table-text">
# <img alt="" src="http://1e49bc5171d173577ecd-1323f4090557a33db01577564f60846c.r80.cf1.rackcdn.com/belt.png"/>
#
#           Feb. 17, 2024
#         </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
#
#
#
#           KO/TKO
#         <img alt="" src="http://1e49bc5171d173577ecd-1323f4090557a33db01577564f60846c.r80.cf1.rackcdn.com/perf.png" style="padding-bottom:3px;margin-right:2px;"/>
# </p>
# <p class="b-fight-details__table-text">
#           Punch
#         </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#           2
#         </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#           3:32
#         </p>
# </td>
# </tr>
# <tr class="b-fight-details__table-row b-fight-details__table-row__hover js-fight-details-click" data-link="http://ufcstats.com/fight-details/c3ef3cb03edde8bb" onclick="doNav('http://ufcstats.com/fight-details/c3ef3cb03edde8bb')">
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
# <a class="b-flag b-flag_style_green" href="http://ufcstats.com/fight-details/c3ef3cb03edde8bb"><i class="b-flag__inner"><i class="b-flag__text">win<i class="b-flag__corner"></i><i class="b-flag__corner-substrate"></i></i></i></a>
# </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/fighter-details/54f64b5e283b0ce7">
#             Ilia Topuria
#           </a>
# </p>
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/fighter-details/fba03cd6cc28dc41">
#             Josh Emmett
#           </a>
# </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#               1
#             </p>
# <p class="b-fight-details__table-text">
#               0
#             </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#               152
#             </p>
# <p class="b-fight-details__table-text">
#               87
#             </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#               3
#             </p>
# <p class="b-fight-details__table-text">
#               0
#             </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#               0
#             </p>
# <p class="b-fight-details__table-text">
#               0
#             </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/event-details/a780d16cf7eed44d">
#             UFC Fight Night: Emmett vs. Topuria
#           </a>
# </p>
# <p class="b-fight-details__table-text">
#
#           Jun. 24, 2023
#         </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
#
#
#
#           U-DEC
#         <img alt="" src="http://1e49bc5171d173577ecd-1323f4090557a33db01577564f60846c.r80.cf1.rackcdn.com/fight.png" style="padding-bottom:3px;margin-right:2px;"/>
# </p>
# <p class="b-fight-details__table-text">
# </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#           5
#         </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#           5:00
#         </p>
# </td>
# </tr>
# <tr class="b-fight-details__table-row b-fight-details__table-row__hover js-fight-details-click" data-link="http://ufcstats.com/fight-details/4a17876e99f6baf3" onclick="doNav('http://ufcstats.com/fight-details/4a17876e99f6baf3')">
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
# <a class="b-flag b-flag_style_green" href="http://ufcstats.com/fight-details/4a17876e99f6baf3"><i class="b-flag__inner"><i class="b-flag__text">win<i class="b-flag__corner"></i><i class="b-flag__corner-substrate"></i></i></i></a>
# </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/fighter-details/54f64b5e283b0ce7">
#             Ilia Topuria
#           </a>
# </p>
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/fighter-details/d9c6f19f958643e9">
#             Bryce Mitchell
#           </a>
# </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#               1
#             </p>
# <p class="b-fight-details__table-text">
#               0
#             </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#               40
#             </p>
# <p class="b-fight-details__table-text">
#               36
#             </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#               0
#             </p>
# <p class="b-fight-details__table-text">
#               1
#             </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#               1
#             </p>
# <p class="b-fight-details__table-text">
#               0
#             </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/event-details/f65a0eb902f9476b">
#             UFC 282: Blachowicz vs. Ankalaev
#           </a>
# </p>
# <p class="b-fight-details__table-text">
#
#           Dec. 10, 2022
#         </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
#
#
#
#           SUB
#         <img alt="" src="http://1e49bc5171d173577ecd-1323f4090557a33db01577564f60846c.r80.cf1.rackcdn.com/perf.png" style="padding-bottom:3px;margin-right:2px;"/>
# </p>
# <p class="b-fight-details__table-text">
#           Arm Triangle
#         </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#           2
#         </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#           3:10
#         </p>
# </td>
# </tr>
# <tr class="b-fight-details__table-row b-fight-details__table-row__hover js-fight-details-click" data-link="http://ufcstats.com/fight-details/a200b5dcbdd2506e" onclick="doNav('http://ufcstats.com/fight-details/a200b5dcbdd2506e')">
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
# <a class="b-flag b-flag_style_green" href="http://ufcstats.com/fight-details/a200b5dcbdd2506e"><i class="b-flag__inner"><i class="b-flag__text">win<i class="b-flag__corner"></i><i class="b-flag__corner-substrate"></i></i></i></a>
# </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/fighter-details/54f64b5e283b0ce7">
#             Ilia Topuria
#           </a>
# </p>
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/fighter-details/4c88a1db5a46c6a4">
#             Jai Herbert
#           </a>
# </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#               1
#             </p>
# <p class="b-fight-details__table-text">
#               1
#             </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#               20
#             </p>
# <p class="b-fight-details__table-text">
#               22
#             </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#               1
#             </p>
# <p class="b-fight-details__table-text">
#               0
#             </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#               0
#             </p>
# <p class="b-fight-details__table-text">
#               0
#             </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/event-details/1d00756835ca67c9">
#             UFC Fight Night: Volkov vs. Aspinall
#           </a>
# </p>
# <p class="b-fight-details__table-text">
#
#           Mar. 19, 2022
#         </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
#
#
#
#           KO/TKO
#         <img alt="" src="http://1e49bc5171d173577ecd-1323f4090557a33db01577564f60846c.r80.cf1.rackcdn.com/perf.png" style="padding-bottom:3px;margin-right:2px;"/>
# </p>
# <p class="b-fight-details__table-text">
#           Punch
#         </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#           2
#         </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#           1:07
#         </p>
# </td>
# </tr>
# <tr class="b-fight-details__table-row b-fight-details__table-row__hover js-fight-details-click" data-link="http://ufcstats.com/fight-details/07468b6347ac5e3d" onclick="doNav('http://ufcstats.com/fight-details/07468b6347ac5e3d')">
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
# <a class="b-flag b-flag_style_green" href="http://ufcstats.com/fight-details/07468b6347ac5e3d"><i class="b-flag__inner"><i class="b-flag__text">win<i class="b-flag__corner"></i><i class="b-flag__corner-substrate"></i></i></i></a>
# </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/fighter-details/54f64b5e283b0ce7">
#             Ilia Topuria
#           </a>
# </p>
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/fighter-details/8866c6f509c19089">
#             Ryan Hall
#           </a>
# </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#               0
#             </p>
# <p class="b-fight-details__table-text">
#               0
#             </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#               18
#             </p>
# <p class="b-fight-details__table-text">
#               10
#             </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#               0
#             </p>
# <p class="b-fight-details__table-text">
#               0
#             </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#               0
#             </p>
# <p class="b-fight-details__table-text">
#               0
#             </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/event-details/8a0be41c0380188d">
#             UFC 264: Poirier vs. McGregor 3
#           </a>
# </p>
# <p class="b-fight-details__table-text">
#
#           Jul. 10, 2021
#         </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
#
#
#
#           KO/TKO
#
#         </p>
# <p class="b-fight-details__table-text">
#           Punches
#         </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#           1
#         </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#           4:47
#         </p>
# </td>
# </tr>
# <tr class="b-fight-details__table-row b-fight-details__table-row__hover js-fight-details-click" data-link="http://ufcstats.com/fight-details/b1be8b41b1a4fd85" onclick="doNav('http://ufcstats.com/fight-details/b1be8b41b1a4fd85')">
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
# <a class="b-flag b-flag_style_green" href="http://ufcstats.com/fight-details/b1be8b41b1a4fd85"><i class="b-flag__inner"><i class="b-flag__text">win<i class="b-flag__corner"></i><i class="b-flag__corner-substrate"></i></i></i></a>
# </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/fighter-details/54f64b5e283b0ce7">
#             Ilia Topuria
#           </a>
# </p>
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/fighter-details/29af297d9f1de0f8">
#             Damon Jackson
#           </a>
# </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#               1
#             </p>
# <p class="b-fight-details__table-text">
#               0
#             </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#               31
#             </p>
# <p class="b-fight-details__table-text">
#               16
#             </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#               0
#             </p>
# <p class="b-fight-details__table-text">
#               0
#             </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#               0
#             </p>
# <p class="b-fight-details__table-text">
#               0
#             </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/event-details/398b440e73d55b8b">
#             UFC Fight Night: Hermansson vs. Vettori
#           </a>
# </p>
# <p class="b-fight-details__table-text">
#
#           Dec. 05, 2020
#         </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
#
#
#
#           KO/TKO
#
#         </p>
# <p class="b-fight-details__table-text">
#           Punch
#         </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#           1
#         </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#           2:38
#         </p>
# </td>
# </tr>
# <tr class="b-fight-details__table-row b-fight-details__table-row__hover js-fight-details-click" data-link="http://ufcstats.com/fight-details/22fe6779c3fa649d" onclick="doNav('http://ufcstats.com/fight-details/22fe6779c3fa649d')">
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
# <a class="b-flag b-flag_style_green" href="http://ufcstats.com/fight-details/22fe6779c3fa649d"><i class="b-flag__inner"><i class="b-flag__text">win<i class="b-flag__corner"></i><i class="b-flag__corner-substrate"></i></i></i></a>
# </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/fighter-details/54f64b5e283b0ce7">
#             Ilia Topuria
#           </a>
# </p>
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/fighter-details/52c2ae6d2f2d2613">
#             Youssef Zalal
#           </a>
# </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#               0
#             </p>
# <p class="b-fight-details__table-text">
#               0
#             </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#               13
#             </p>
# <p class="b-fight-details__table-text">
#               17
#             </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#               5
#             </p>
# <p class="b-fight-details__table-text">
#               0
#             </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#               5
#             </p>
# <p class="b-fight-details__table-text">
#               1
#             </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
# <a class="b-link b-link_style_black" href="http://ufcstats.com/event-details/fd4578cac86d75ca">
#             UFC Fight Night: Moraes vs. Sandhagen
#           </a>
# </p>
# <p class="b-fight-details__table-text">
#
#           Oct. 10, 2020
#         </p>
# </td>
# <td class="b-fight-details__table-col l-page_align_left">
# <p class="b-fight-details__table-text">
#
#
#
#           U-DEC
#
#         </p>
# <p class="b-fight-details__table-text">
# </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#           3
#         </p>
# </td>
# <td class="b-fight-details__table-col">
# <p class="b-fight-details__table-text">
#           5:00
#         </p>
# </td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </section>
# <footer class="b-foot">
# <div class="b-foot__inner">
# <div class="l-page__container clearfix">
# <div class="b-foot__right">
# <div class="b-foot__list-inner">
# <h4 class="b-foot__list-title">
#             Navigation
#           </h4>
# <ul class="b-foot__list">
# <li class="b-foot__item">
# <a class="b-foot__link" href="/statistics/events/">
#                 Events &amp; Fights
#               </a>
# </li>
# <li class="b-foot__item">
# <a class="b-foot__link" href="/statistics/fighters">
#                 Fighters
#               </a>
# </li>
# <li class="b-foot__item">
# <a class="b-foot__link" href="http://statleaders.ufc.com" target="_blank">
#                 Stat Leaders
#               </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="b-foot__logo">
# <a href="/">
# <img alt="" src="http://1e49bc5171d173577ecd-1323f4090557a33db01577564f60846c.r80.cf1.rackcdn.com/ufc-stats-foot-logo.png"/>
# </a>
# <div class="b-foot__copy-inner">
#           © All Rights Reserved |
#           <a class="b-foot__copy-link" href="https://ufc.com/terms" target="_blank">Terms of Use</a> |
#           <a class="b-foot__copy-link" href="https://ufc.com/privacy-policy" target="_blank">Privacy Policy</a>
# </div>
# </div>
# </div>
# </div>
# </footer>
# <script src="//ajax.googleapis.com/ajax/libs/jquery/1.10.2/jquery.min.js"></script>
# <script src="http://code.jquery.com/jquery-1.9.1.js"></script>
# <script src="http://code.jquery.com/ui/1.10.3/jquery-ui.js"></script>
# <link href="http://code.jquery.com/ui/1.10.3/themes/smoothness/jquery-ui.css" rel="stylesheet">
# <script>window.jQuery || document.write('<script src="/js/vendor/jquery-1.10.2.min.js"><\/script>')</script>
# <script src="/js/vendor/jquery.validate.min.js" type="text/javascript"></script>
# <script src="/js/plugins.js"></script>
# <script src="/js/main.js?ver=861522"></script>
# <script type="text/javascript">
#     $(document).ready(function () {
#         $(function () {
#             $("#dialog").dialog({
#
#                 autoOpen: false,
#                 modal: true,
#                 show: {
#                     effect: "blind",
#                     duration: 1000
#                 },
#                 hide: {
#                     effect: "fold",
#                     duration: 1000
#                 }
#
#             });
#         });
#     }
#
#     );
#     $("#opener").click(function () {
#         $("#dialog").dialog("open");
#     });
#     $("#opener").click(function () {
#         var state = true;
#         if (state) {
#             $("#dialog").animate({
#                 backgroundColor: "white",
#                 color: "black"
#
#             }, 1000);
#         }
#     });
#
# </script>
# <script type="text/javascript">
#
#  /*window.onload = function (){
#      // location.pathname.split( '/' )
#      theUrl = window.location.host;
#
#
#      if(theUrl === 'hosteddb.fightmetric.com'){
#          window.location.replace("http://www.fightmetric.com/statistics/events/upcoming");
#      }
#
#      //alert(theUrl);
#   }*/
#   //window.onpaint = handleHosted;
# </script>
# </link></body>
# </html>

# %%
print(soup.head.title.text)
# Out:
#     Stats | UFC

# %% [markdown]
# **Ejercicio 1.** (1 punto) Extrae el nombre del luchador, así como su record y alias

# %%
#Nombre
def getName(soup):
    nombre = soup.find(class_="b-content__title-highlight").text.strip()
    return nombre
    
#Record
def getRecord(soup):
    record = soup.find(class_="b-content__title-record").text.strip()
    return record

#NickName
def getNickName(soup):
    nickname = soup.find(class_="b-content__Nickname").text.strip()
    return nickname

nombre = getName(soup)
record = getRecord(soup)
nickname= getNickName(soup)

print(record)
print(nombre)
print(nickname)
# Out:
# Record: 17-0-0
# Ilia Topuria
# El Matador

# %%
#Hacemos un diccionario con las stats iniciales
def getInitialStats(soup):
    dict ={"NAME":"","RECORD":"","NICKNAME":""}
    dict["NAME"] = getName(soup)
    dict["RECORD"] = getRecord(soup)
    dict["NICKNAME"] = getNickName(soup)
    return dict

initialStatsDict = getInitialStats(soup)
print(initialStatsDict)
# Out:
# {'NAME': 'Ilia Topuria', 'RECORD': 'Record: 17-0-0', 'NICKNAME': 'El Matador'}

# %% [markdown]
# **Ejercicio 2.** (2 puntos) Extrae las caracteristicas básicas del luchador: HEIGHT, WEIGHT, REACH, STANCE, DOB

# %%
def cleanBasicStat(cadena):
    basicStat = ""
    if ":" in cadena:
        basicStat = cadena.split(":")[1].strip()
    return basicStat

def getBasicStatsList(soup):
    lista = soup.find(class_="b-list__box-list")
    cleanStats = []
    for elem in lista.find_all('li', recursive=False):
        cleanStats.append(cleanBasicStat(elem.text))
    return cleanStats
    


cleanStats = getBasicStatsList(soup)
print(cleanStats)
# Out:
# ['5\' 7"', '155 lbs.', '69"', 'Orthodox', 'Jan 21, 1997']

# %%
#Utiliza las funciones anteriores para extraer todos los datos
def getBasicStats(soup):
    #Obtenemos la lista de estadísticas básicas
    cleanStats = getBasicStatsList(soup)
    
    #Haz un diccionario con los valores
    basicStatsDict = {"HEIGHT":"", "WEIGHT":"", "REACH":"","STANCE":"","DOB":""}

    #Asignamos los valores (despues veremos un método más pro)
    basicStatsDict["HEIGHT"] = cleanStats[0]
    basicStatsDict["WEIGHT"] = cleanStats[1]
    basicStatsDict["REACH"] = cleanStats[2]
    basicStatsDict["STANCE"] = cleanStats[3]
    basicStatsDict["DOB"] = cleanStats[4]
    return basicStatsDict
    
basicStatsDict = getBasicStats(soup)
print(basicStatsDict)
# Out:
# {'HEIGHT': '5\' 7"', 'WEIGHT': '155 lbs.', 'REACH': '69"', 'STANCE': 'Orthodox', 'DOB': 'Jan 21, 1997'}

# %% [markdown]
# **Ejercicio 3.** (2 puntos) Extrae las caracteristicas de la carrera del luchador:
# - **SLpM** - Golpes significativos conectados por minuto.
# - **Str. Acc.** - Precisión en golpes significativos.
# - **SApM** - Golpes significativos absorbidos por minuto.
# - **Str. Def.** - Defensa ante golpes significativos (porcentaje de golpes del oponente que no conectaron).
# - **TD Avg.** - Derribos promedio logrados por cada 15 minutos.
# - **TD Acc.** - Precisión en derribos.
# - **TD Def.** - Defensa ante derribos (porcentaje de intentos de derribo del oponente que no tuvieron éxito).
# - **Sub. Avg.** - Intentos de sumisión promedio por cada 15 minutos.

# %%
#Obten solo los resultados, en el siguiente apartado los adaptamos con diccionarios
def getCareerStatsList(soup):
    cleanCareerStats =[]
    todo = soup.find(class_="b-list__info-box-left clearfix")
    div1 = todo.find(class_='b-list__info-box-left')
    ul1 = div1.find(class_='b-list__box-list b-list__box-list_margin-top')
    div2 = todo.find(class_='b-list__info-box-right b-list__info-box_style-margin-right')
    ul2 = div2.find(class_='b-list__box-list b-list__box-list_margin-top')
    for elem in ul1.find_all('li', recursive=False):
        aux = cleanBasicStat(elem.text)
        if aux != "":
            cleanCareerStats.append(aux)
    for elem in ul2.find_all('li', recursive=False):
        aux = cleanBasicStat(elem.text)
        if aux != "":
            cleanCareerStats.append(aux)
    return cleanCareerStats

cleanCareerStats = getCareerStatsList(soup)
print(cleanCareerStats)
# Out:
# ['4.81', '48%', '3.83', '64%', '1.96', '61%', '93%', '1.1']

# %%
def getCareerStats(soup):
    cleanCareerStats = getCareerStatsList(soup)
    #Hacemos otro diccionario
    dictCS = {"SLpM":"", "Str. Acc.":"", "SApM":"","Str. Def.":"","TD Avg.":"", "TD Acc.":"", "TD Def.":"", "Sub. Avg.":""}
    dictCS = dict(zip(dictCS.keys(), cleanCareerStats))
    return dictCS
    
careerStatsDict =  getCareerStats(soup)  
print(careerStatsDict)
# Out:
# {'SLpM': '4.81', 'Str. Acc.': '48%', 'SApM': '3.83', 'Str. Def.': '64%', 'TD Avg.': '1.96', 'TD Acc.': '61%', 'TD Def.': '93%', 'Sub. Avg.': '1.1'}

# %% [markdown]
# **Ejercicio 4** (1 punto). El siguiente paso es unificar las funciones anteriores. Crea una función *extractFighterStats* que obtenga una lista de las estadísticas extraidas de la página del luchador proporcionada.

# %% [markdown]
# Para ello, vamos a tener que es unificar el diccionario. Existen tres metodos distintos, vamos a utilizar el más directo y más elegante

# %%
#Asi se mezclan los diccionarios
fighterDict = initialStatsDict | basicStatsDict | careerStatsDict
print(fighterDict)

#Y así se obtienen las claves y valores. Puede que te sirva para despues:
print(fighterDict.keys())
print(fighterDict.values())
# Out:
# {'NAME': 'Ilia Topuria', 'RECORD': 'Record: 17-0-0', 'NICKNAME': 'El Matador', 'HEIGHT': '5\' 7"', 'WEIGHT': '155 lbs.', 'REACH': '69"', 'STANCE': 'Orthodox', 'DOB': 'Jan 21, 1997', 'SLpM': '4.81', 'Str. Acc.': '48%', 'SApM': '3.83', 'Str. Def.': '64%', 'TD Avg.': '1.96', 'TD Acc.': '61%', 'TD Def.': '93%', 'Sub. Avg.': '1.1'}
# dict_keys(['NAME', 'RECORD', 'NICKNAME', 'HEIGHT', 'WEIGHT', 'REACH', 'STANCE', 'DOB', 'SLpM', 'Str. Acc.', 'SApM', 'Str. Def.', 'TD Avg.', 'TD Acc.', 'TD Def.', 'Sub. Avg.'])
# dict_values(['Ilia Topuria', 'Record: 17-0-0', 'El Matador', '5\' 7"', '155 lbs.', '69"', 'Orthodox', 'Jan 21, 1997', '4.81', '48%', '3.83', '64%', '1.96', '61%', '93%', '1.1'])

# %%
def extractFighterStats(urlIn):
    #Obtenemos la página con soup
    page = requests.get(urlIn)
    soup = BeautifulSoup(page.text, 'html.parser')
    
    #Adquirimos los diccionarios (llamando a las funciones ya hechas)
    dictInitial = getInitialStats(soup)
    dictBasic = getBasicStats(soup)
    dictCareer = getCareerStats(soup)

    #Hacemos un diccionario juntando los diccionarios anteriores
    dictFighter = dictInitial | dictBasic | dictCareer

    #Devolvemos una lista con los valores
    return list(dictFighter.values())

listFighter = extractFighterStats(url)
print(listFighter)
# Out:
# ['Ilia Topuria', 'Record: 17-0-0', 'El Matador', '5\' 7"', '155 lbs.', '69"', 'Orthodox', 'Jan 21, 1997', '4.81', '48%', '3.83', '64%', '1.96', '61%', '93%', '1.1']

# %% [markdown]
# **Ejercicio 5** (1 puntos). Ahora vamos a probar a extraer los datos de varios luchadores. Explora la página `http://ufcstats.com/statistics/fighters`, la cual lista distintos peleadores, extrae todos los enlaces y carga las stats de los nombres.

# %%
urlFighters = "http://ufcstats.com/statistics/fighters"
page = requests.get(urlFighters)
soup = BeautifulSoup(page.text, 'html.parser')  # le pasamos el texto en HTML para que lo analice

# %%
def extractFighterLinksList(soup):
    tabla = soup.find(class_="b-statistics__table")
    retList = tabla.find_all(class_="b-link b-link_style_black")
    nuevaLista = []
    for elem in retList:
        nuevaLista.append(elem.get("href"))
    return nuevaLista
                
linkList = extractFighterLinksList(soup)
print(linkList)
# Out:
# ['http://ufcstats.com/fighter-details/93fe7332d16c6ad9', 'http://ufcstats.com/fighter-details/93fe7332d16c6ad9', 'http://ufcstats.com/fighter-details/93fe7332d16c6ad9', 'http://ufcstats.com/fighter-details/15df64c02b6b0fde', 'http://ufcstats.com/fighter-details/15df64c02b6b0fde', 'http://ufcstats.com/fighter-details/15df64c02b6b0fde', 'http://ufcstats.com/fighter-details/59a9d6dac61c2540', 'http://ufcstats.com/fighter-details/59a9d6dac61c2540', 'http://ufcstats.com/fighter-details/59a9d6dac61c2540', 'http://ufcstats.com/fighter-details/4961467134abd8be', 'http://ufcstats.com/fighter-details/4961467134abd8be', 'http://ufcstats.com/fighter-details/4961467134abd8be', 'http://ufcstats.com/fighter-details/b361180739bed4b0', 'http://ufcstats.com/fighter-details/b361180739bed4b0', 'http://ufcstats.com/fighter-details/b361180739bed4b0', 'http://ufcstats.com/fighter-details/3329d692aea4dc28', 'http://ufcstats.com/fighter-details/3329d692aea4dc28', 'http://ufcstats.com/fighter-details/3329d692aea4dc28', 'http://ufcstats.com/fighter-details/841695e02c99a521', 'http://ufcstats.com/fighter-details/841695e02c99a521', 'http://ufcstats.com/fighter-details/841695e02c99a521', 'http://ufcstats.com/fighter-details/2f5cbecbbe18bac4', 'http://ufcstats.com/fighter-details/2f5cbecbbe18bac4', 'http://ufcstats.com/fighter-details/2f5cbecbbe18bac4', 'http://ufcstats.com/fighter-details/c0ed7b208197e8de', 'http://ufcstats.com/fighter-details/c0ed7b208197e8de', 'http://ufcstats.com/fighter-details/c0ed7b208197e8de', 'http://ufcstats.com/fighter-details/5140122c3eecd307', 'http://ufcstats.com/fighter-details/5140122c3eecd307', 'http://ufcstats.com/fighter-details/5140122c3eecd307', 'http://ufcstats.com/fighter-details/c9f6385af6df66d7', 'http://ufcstats.com/fighter-details/c9f6385af6df66d7', 'http://ufcstats.com/fighter-details/c9f6385af6df66d7', 'http://ufcstats.com/fighter-details/aa6e591c2a2cdecd', 'http://ufcstats.com/fighter-details/aa6e591c2a2cdecd', 'http://ufcstats.com/fighter-details/aa6e591c2a2cdecd', 'http://ufcstats.com/fighter-details/7279654c7674cd24', 'http://ufcstats.com/fighter-details/7279654c7674cd24', 'http://ufcstats.com/fighter-details/7279654c7674cd24', 'http://ufcstats.com/fighter-details/f689bd7bbd14b392', 'http://ufcstats.com/fighter-details/f689bd7bbd14b392', 'http://ufcstats.com/fighter-details/f689bd7bbd14b392', 'http://ufcstats.com/fighter-details/1c5879330d42255f', 'http://ufcstats.com/fighter-details/1c5879330d42255f', 'http://ufcstats.com/fighter-details/1c5879330d42255f', 'http://ufcstats.com/fighter-details/989b85f6540c86b1', 'http://ufcstats.com/fighter-details/989b85f6540c86b1', 'http://ufcstats.com/fighter-details/989b85f6540c86b1', 'http://ufcstats.com/fighter-details/2620f3eb21c79614', 'http://ufcstats.com/fighter-details/2620f3eb21c79614', 'http://ufcstats.com/fighter-details/2620f3eb21c79614', 'http://ufcstats.com/fighter-details/83b00f7597e5ac83', 'http://ufcstats.com/fighter-details/83b00f7597e5ac83', 'http://ufcstats.com/fighter-details/83b00f7597e5ac83', 'http://ufcstats.com/fighter-details/a77633a989013265', 'http://ufcstats.com/fighter-details/a77633a989013265', 'http://ufcstats.com/fighter-details/a77633a989013265', 'http://ufcstats.com/fighter-details/79cb2a690b9ba5e8', 'http://ufcstats.com/fighter-details/79cb2a690b9ba5e8', 'http://ufcstats.com/fighter-details/79cb2a690b9ba5e8', 'http://ufcstats.com/fighter-details/1338e2c7480bdf9e', 'http://ufcstats.com/fighter-details/1338e2c7480bdf9e', 'http://ufcstats.com/fighter-details/1338e2c7480bdf9e', 'http://ufcstats.com/fighter-details/0e9869d712e81f8f', 'http://ufcstats.com/fighter-details/0e9869d712e81f8f', 'http://ufcstats.com/fighter-details/0e9869d712e81f8f', 'http://ufcstats.com/fighter-details/7a846fcbf182a7c8', 'http://ufcstats.com/fighter-details/7a846fcbf182a7c8', 'http://ufcstats.com/fighter-details/7a846fcbf182a7c8', 'http://ufcstats.com/fighter-details/ebc5af72ad5a28cb', 'http://ufcstats.com/fighter-details/ebc5af72ad5a28cb', 'http://ufcstats.com/fi ...

# %% [markdown]
# **Ejercicio 6 (1 punto)**. Es momento de hacer nuestro mini dataset de luchadores. Para ello, itera la lista de enlaces, y extrae las stats de todos ellos. Cada vez que extraigas stats de un peleador, pon tu programa a dormir por 1 segundo ( utiliza `time.sleep(1)`)

# %%
import time

def extractFighterListOfLists(linkList):
    lists=[]
    i=0
    for link in linkList:
        print("link: ", link)
        stats = extractFighterStats(link)
        print("Extracted {0} stat: ".format(i),stats)
        time.sleep(1)
        i = i+1
        lists.append(stats)
    return lists

listOfLists = extractFighterListOfLists(linkList)
# Out:
# link:  http://ufcstats.com/fighter-details/93fe7332d16c6ad9
# Extracted 0 stat:  ['Tom Aaron', 'Record: 5-3-0', '', '--', '155 lbs.', '--', '', 'Jul 13, 1978', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/93fe7332d16c6ad9
# Extracted 1 stat:  ['Tom Aaron', 'Record: 5-3-0', '', '--', '155 lbs.', '--', '', 'Jul 13, 1978', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/93fe7332d16c6ad9
# Extracted 2 stat:  ['Tom Aaron', 'Record: 5-3-0', '', '--', '155 lbs.', '--', '', 'Jul 13, 1978', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/15df64c02b6b0fde
# Extracted 3 stat:  ['Danny Abbadi', 'Record: 4-6-0', 'The Assassin', '5\' 11"', '155 lbs.', '--', 'Orthodox', 'Jul 03, 1983', '3.29', '38%', '4.41', '57%', '0.00', '0%', '77%', '0.0']
# link:  http://ufcstats.com/fighter-details/15df64c02b6b0fde
# Extracted 4 stat:  ['Danny Abbadi', 'Record: 4-6-0', 'The Assassin', '5\' 11"', '155 lbs.', '--', 'Orthodox', 'Jul 03, 1983', '3.29', '38%', '4.41', '57%', '0.00', '0%', '77%', '0.0']
# link:  http://ufcstats.com/fighter-details/15df64c02b6b0fde
# Extracted 5 stat:  ['Danny Abbadi', 'Record: 4-6-0', 'The Assassin', '5\' 11"', '155 lbs.', '--', 'Orthodox', 'Jul 03, 1983', '3.29', '38%', '4.41', '57%', '0.00', '0%', '77%', '0.0']
# link:  http://ufcstats.com/fighter-details/59a9d6dac61c2540
# Extracted 6 stat:  ['Nariman Abbasov', 'Record: 28-4-0', 'Bayraktar', '5\' 8"', '155 lbs.', '66"', 'Orthodox', 'Feb 01, 1994', '3.00', '20%', '5.67', '46%', '0.00', '0%', '66%', '0.0']
# link:  http://ufcstats.com/fighter-details/59a9d6dac61c2540
# Extracted 7 stat:  ['Nariman Abbasov', 'Record: 28-4-0', 'Bayraktar', '5\' 8"', '155 lbs.', '66"', 'Orthodox', 'Feb 01, 1994', '3.00', '20%', '5.67', '46%', '0.00', '0%', '66%', '0.0']
# link:  http://ufcstats.com/fighter-details/59a9d6dac61c2540
# Extracted 8 stat:  ['Nariman Abbasov', 'Record: 28-4-0', 'Bayraktar', '5\' 8"', '155 lbs.', '66"', 'Orthodox', 'Feb 01, 1994', '3.00', '20%', '5.67', '46%', '0.00', '0%', '66%', '0.0']
# link:  http://ufcstats.com/fighter-details/4961467134abd8be
# Extracted 9 stat:  ['Darion Abbey', 'Record: 9-5-0', '', '6\' 2"', '265 lbs.', '80"', 'Orthodox', 'Feb 25, 1993', '8.44', '50%', '14.06', '28%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/4961467134abd8be
# Extracted 10 stat:  ['Darion Abbey', 'Record: 9-5-0', '', '6\' 2"', '265 lbs.', '80"', 'Orthodox', 'Feb 25, 1993', '8.44', '50%', '14.06', '28%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/4961467134abd8be
# Extracted 11 stat:  ['Darion Abbey', 'Record: 9-5-0', '', '6\' 2"', '265 lbs.', '80"', 'Orthodox', 'Feb 25, 1993', '8.44', '50%', '14.06', '28%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/b361180739bed4b0
# Extracted 12 stat:  ['David Abbott', 'Record: 10-15-0', 'Tank', '6\' 0"', '265 lbs.', '--', 'Switch', 'Apr 26, 1965', '1.35', '30%', '3.55', '38%', '1.07', '33%', '66%', '0.0']
# link:  http://ufcstats.com/fighter-details/b361180739bed4b0
# Extracted 13 stat:  ['David Abbott', 'Record: 10-15-0', 'Tank', '6\' 0"', '265 lbs.', '--', 'Switch', 'Apr 26, 1965', '1.35', '30%', '3.55', '38%', '1.07', '33%', '66%', '0.0']
# link:  http://ufcstats.com/fighter-details/b361180739bed4b0
# Extracted 14 stat:  ['David Abbott', 'Record: 10-15-0', 'Tank', '6\' 0"', '265 lbs.', '--', 'Switch', 'Apr 26, 1965', '1.35', '30%', '3.55', '38%', '1.07', '33%', '66%', '0.0']
# link:  http://ufcstats.com/fighter-details/3329d692aea4dc28
# Extracted 15 stat:  ['Hamdy Abdelwahab', 'Record: 7-1-0 (1 NC)', 'The Hammer', '6\' 2"', '265 lbs.', '72"', 'Southpaw', 'Jan 22, 1993', '4.27', '55%', '3.67', '51%', '3.25', '65%', '100%', '0.0']
# link:  http://ufcstats.com/fighter-details/3329d692aea4dc28
# Extracted 16 stat:  ['Hamdy Abdelwahab', 'Record: 7-1-0 (1 NC)', 'The Hammer', '6\' 2"', '265 lbs.', '72"', 'Southpaw', 'Jan 22, 1993', '4.27', '55%', '3.67', '51%', '3.25', '65%', '100%', '0.0']
# link:  http://ufcstats.com/fighter-details/3329d692aea4dc28
# Extracted 17 stat:  ['Hamdy Abdelwahab', 'Record: 7-1-0 (1 NC)', 'The Hammer', '6\' 2"', '265 lbs.', '72"', 'Southpaw', 'Jan 22, 1993', '4.27', '55%', '3.67', '51%', '3.25', '65%', '100%', '0.0']
# link:  http://ufcstats.com/fighter-details/841695e02c99a521
# Extracted 18 stat:  ['Mansur Abdul-Malik', 'Record: 9-0-1', '', '6\' 2"', '185 lbs.', '80"', 'Orthodox', 'Oct 07, 1997', '4.18', '48%', '3.46', '51%', '0.94', '50%', '83%', '0.5']
# link:  http://ufcstats.com/fighter-details/841695e02c99a521
# Extracted 19 stat:  ['Mansur Abdul-Malik', 'Record: 9-0-1', '', '6\' 2"', '185 lbs.', '80"', 'Orthodox', 'Oct 07, 1997', '4.18', '48%', '3.46', '51%', '0.94', '50%', '83%', '0.5']
# link:  http://ufcstats.com/fighter-details/841695e02c99a521
# Extracted 20 stat:  ['Mansur Abdul-Malik', 'Record: 9-0-1', '', '6\' 2"', '185 lbs.', '80"', 'Orthodox', 'Oct 07, 1997', '4.18', '48%', '3.46', '51%', '0.94', '50%', '83%', '0.5']
# link:  http://ufcstats.com/fighter-details/2f5cbecbbe18bac4
# Extracted 21 stat:  ['Shamil Abdurakhimov', 'Record: 20-8-0', 'Abrek', '6\' 3"', '235 lbs.', '76"', 'Orthodox', 'Sep 02, 1981', '2.41', '44%', '3.02', '55%', '1.01', '23%', '45%', '0.1']
# link:  http://ufcstats.com/fighter-details/2f5cbecbbe18bac4
# Extracted 22 stat:  ['Shamil Abdurakhimov', 'Record: 20-8-0', 'Abrek', '6\' 3"', '235 lbs.', '76"', 'Orthodox', 'Sep 02, 1981', '2.41', '44%', '3.02', '55%', '1.01', '23%', '45%', '0.1']
# link:  http://ufcstats.com/fighter-details/2f5cbecbbe18bac4
# Extracted 23 stat:  ['Shamil Abdurakhimov', 'Record: 20-8-0', 'Abrek', '6\' 3"', '235 lbs.', '76"', 'Orthodox', 'Sep 02, 1981', '2.41', '44%', '3.02', '55%', '1.01', '23%', '45%', '0.1']
# link:  http://ufcstats.com/fighter-details/c0ed7b208197e8de
# Extracted 24 stat:  ['Hiroyuki Abe', 'Record: 8-15-3 (1 NC)', 'Abe Ani', '5\' 6"', '145 lbs.', '--', 'Orthodox', 'Feb 09, 1970', '1.71', '36%', '3.11', '63%', '0.00', '0%', '33%', '0.0']
# link:  http://ufcstats.com/fighter-details/c0ed7b208197e8de
# Extracted 25 stat:  ['Hiroyuki Abe', 'Record: 8-15-3 (1 NC)', 'Abe Ani', '5\' 6"', '145 lbs.', '--', 'Orthodox', 'Feb 09, 1970', '1.71', '36%', '3.11', '63%', '0.00', '0%', '33%', '0.0']
# link:  http://ufcstats.com/fighter-details/c0ed7b208197e8de
# Extracted 26 stat:  ['Hiroyuki Abe', 'Record: 8-15-3 (1 NC)', 'Abe Ani', '5\' 6"', '145 lbs.', '--', 'Orthodox', 'Feb 09, 1970', '1.71', '36%', '3.11', '63%', '0.00', '0%', '33%', '0.0']
# link:  http://ufcstats.com/fighter-details/5140122c3eecd307
# Extracted 27 stat:  ['Daichi Abe', 'Record: 6-2-0', '', '5\' 11"', '170 lbs.', '71"', 'Orthodox', 'Nov 27, 1991', '3.80', '33%', '4.49', '56%', '0.33', '50%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/5140122c3eecd307
# Extracted 28 stat:  ['Daichi Abe', 'Record: 6-2-0', '', '5\' 11"', '170 lbs.', '71"', 'Orthodox', 'Nov 27, 1991', '3.80', '33%', '4.49', '56%', '0.33', '50%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/5140122c3eecd307
# Extracted 29 stat:  ['Daichi Abe', 'Record: 6-2-0', '', '5\' 11"', '170 lbs.', '71"', 'Orthodox', 'Nov 27, 1991', '3.80', '33%', '4.49', '56%', '0.33', '50%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/c9f6385af6df66d7
# Extracted 30 stat:  ['Papy Abedi', 'Record: 10-4-0', 'Makambo', '5\' 11"', '185 lbs.', '--', 'Southpaw', 'Jun 30, 1978', '2.80', '55%', '3.15', '48%', '3.47', '57%', '50%', '1.3']
# link:  http://ufcstats.com/fighter-details/c9f6385af6df66d7
# Extracted 31 stat:  ['Papy Abedi', 'Record: 10-4-0', 'Makambo', '5\' 11"', '185 lbs.', '--', 'Southpaw', 'Jun 30, 1978', '2.80', '55%', '3.15', '48%', '3.47', '57%', '50%', '1.3']
# link:  http://ufcstats.com/fighter-details/c9f6385af6df66d7
# Extracted 32 stat:  ['Papy Abedi', 'Record: 10-4-0', 'Makambo', '5\' 11"', '185 lbs.', '--', 'Southpaw', 'Jun 30, 1978', '2.80', '55%', '3.15', '48%', '3.47', '57%', '50%', '1.3']
# link:  http://ufcstats.com/fighter-details/aa6e591c2a2cdecd
# Extracted 33 stat:  ['Ricardo Abreu', 'Record: 5-1-0', 'Demente', '5\' 11"', '185 lbs.', '--', 'Orthodox', 'Apr 27, 1984', '3.79', '31%', '3.98', '68%', '2.13', '42%', '100%', '0.7']
# link:  http://ufcstats.com/fighter-details/aa6e591c2a2cdecd
# Extracted 34 stat:  ['Ricardo Abreu', 'Record: 5-1-0', 'Demente', '5\' 11"', '185 lbs.', '--', 'Orthodox', 'Apr 27, 1984', '3.79', '31%', '3.98', '68%', '2.13', '42%', '100%', '0.7']
# link:  http://ufcstats.com/fighter-details/aa6e591c2a2cdecd
# Extracted 35 stat:  ['Ricardo Abreu', 'Record: 5-1-0', 'Demente', '5\' 11"', '185 lbs.', '--', 'Orthodox', 'Apr 27, 1984', '3.79', '31%', '3.98', '68%', '2.13', '42%', '100%', '0.7']
# link:  http://ufcstats.com/fighter-details/7279654c7674cd24
# Extracted 36 stat:  ['Klidson Abreu', 'Record: 15-4-0 (1 NC)', 'White Bear', '6\' 0"', '205 lbs.', '74"', 'Orthodox', 'Dec 24, 1992', '2.05', '40%', '2.90', '55%', '0.64', '20%', '80%', '0.0']
# link:  http://ufcstats.com/fighter-details/7279654c7674cd24
# Extracted 37 stat:  ['Klidson Abreu', 'Record: 15-4-0 (1 NC)', 'White Bear', '6\' 0"', '205 lbs.', '74"', 'Orthodox', 'Dec 24, 1992', '2.05', '40%', '2.90', '55%', '0.64', '20%', '80%', '0.0']
# link:  http://ufcstats.com/fighter-details/7279654c7674cd24
# Extracted 38 stat:  ['Klidson Abreu', 'Record: 15-4-0 (1 NC)', 'White Bear', '6\' 0"', '205 lbs.', '74"', 'Orthodox', 'Dec 24, 1992', '2.05', '40%', '2.90', '55%', '0.64', '20%', '80%', '0.0']
# link:  http://ufcstats.com/fighter-details/f689bd7bbd14b392
# Extracted 39 stat:  ['Cyborg Abreu', 'Record: 0-0-0', '', '--', '--', '--', '', 'Dec 20, 1980', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/f689bd7bbd14b392
# Extracted 40 stat:  ['Cyborg Abreu', 'Record: 0-0-0', '', '--', '--', '--', '', 'Dec 20, 1980', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/f689bd7bbd14b392
# Extracted 41 stat:  ['Cyborg Abreu', 'Record: 0-0-0', '', '--', '--', '--', '', 'Dec 20, 1980', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/1c5879330d42255f
# Extracted 42 stat:  ['Daniel Acacio', 'Record: 30-18-0', '', '5\' 8"', '180 lbs.', '--', 'Orthodox', 'Dec 27, 1977', '3.52', '36%', '2.85', '62%', '0.33', '20%', '81%', '0.0']
# link:  http://ufcstats.com/fighter-details/1c5879330d42255f
# Extracted 43 stat:  ['Daniel Acacio', 'Record: 30-18-0', '', '5\' 8"', '180 lbs.', '--', 'Orthodox', 'Dec 27, 1977', '3.52', '36%', '2.85', '62%', '0.33', '20%', '81%', '0.0']
# link:  http://ufcstats.com/fighter-details/1c5879330d42255f
# Extracted 44 stat:  ['Daniel Acacio', 'Record: 30-18-0', '', '5\' 8"', '180 lbs.', '--', 'Orthodox', 'Dec 27, 1977', '3.52', '36%', '2.85', '62%', '0.33', '20%', '81%', '0.0']
# link:  http://ufcstats.com/fighter-details/989b85f6540c86b1
# Extracted 45 stat:  ['John Adajar', 'Record: 6-2-0', 'The Outlaw', '5\' 9"', '170 lbs.', '75"', 'Orthodox', 'Jun 22, 1991', '3.90', '52%', '6.28', '44%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/989b85f6540c86b1
# Extracted 46 stat:  ['John Adajar', 'Record: 6-2-0', 'The Outlaw', '5\' 9"', '170 lbs.', '75"', 'Orthodox', 'Jun 22, 1991', '3.90', '52%', '6.28', '44%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/989b85f6540c86b1
# Extracted 47 stat:  ['John Adajar', 'Record: 6-2-0', 'The Outlaw', '5\' 9"', '170 lbs.', '75"', 'Orthodox', 'Jun 22, 1991', '3.90', '52%', '6.28', '44%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/2620f3eb21c79614
# Extracted 48 stat:  ['Scott Adams', 'Record: 8-1-0', '', '6\' 0"', '225 lbs.', '--', 'Southpaw', '--', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/2620f3eb21c79614
# Extracted 49 stat:  ['Scott Adams', 'Record: 8-1-0', '', '6\' 0"', '225 lbs.', '--', 'Southpaw', '--', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/2620f3eb21c79614
# Extracted 50 stat:  ['Scott Adams', 'Record: 8-1-0', '', '6\' 0"', '225 lbs.', '--', 'Southpaw', '--', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/83b00f7597e5ac83
# Extracted 51 stat:  ['Juan Adams', 'Record: 5-3-0', 'The Kraken', '6\' 5"', '265 lbs.', '80"', 'Orthodox', 'Jan 16, 1992', '7.09', '55%', '4.06', '34%', '0.91', '66%', '57%', '0.0']
# link:  http://ufcstats.com/fighter-details/83b00f7597e5ac83
# Extracted 52 stat:  ['Juan Adams', 'Record: 5-3-0', 'The Kraken', '6\' 5"', '265 lbs.', '80"', 'Orthodox', 'Jan 16, 1992', '7.09', '55%', '4.06', '34%', '0.91', '66%', '57%', '0.0']
# link:  http://ufcstats.com/fighter-details/83b00f7597e5ac83
# Extracted 53 stat:  ['Juan Adams', 'Record: 5-3-0', 'The Kraken', '6\' 5"', '265 lbs.', '80"', 'Orthodox', 'Jan 16, 1992', '7.09', '55%', '4.06', '34%', '0.91', '66%', '57%', '0.0']
# link:  http://ufcstats.com/fighter-details/a77633a989013265
# Extracted 54 stat:  ['Anthony Adams', 'Record: 8-2-0', 'Sugafoot', '6\' 1"', '185 lbs.', '76"', 'Orthodox', 'Jan 13, 1988', '3.17', '41%', '5.93', '44%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/a77633a989013265
# Extracted 55 stat:  ['Anthony Adams', 'Record: 8-2-0', 'Sugafoot', '6\' 1"', '185 lbs.', '76"', 'Orthodox', 'Jan 13, 1988', '3.17', '41%', '5.93', '44%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/a77633a989013265
# Extracted 56 stat:  ['Anthony Adams', 'Record: 8-2-0', 'Sugafoot', '6\' 1"', '185 lbs.', '76"', 'Orthodox', 'Jan 13, 1988', '3.17', '41%', '5.93', '44%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/79cb2a690b9ba5e8
# Extracted 57 stat:  ['Zarrukh Adashev', 'Record: 4-4-0', 'The Lion', '5\' 5"', '125 lbs.', '65"', 'Southpaw', 'Jul 29, 1992', '3.65', '40%', '3.04', '64%', '0.00', '0%', '100%', '0.5']
# link:  http://ufcstats.com/fighter-details/79cb2a690b9ba5e8
# Extracted 58 stat:  ['Zarrukh Adashev', 'Record: 4-4-0', 'The Lion', '5\' 5"', '125 lbs.', '65"', 'Southpaw', 'Jul 29, 1992', '3.65', '40%', '3.04', '64%', '0.00', '0%', '100%', '0.5']
# link:  http://ufcstats.com/fighter-details/79cb2a690b9ba5e8
# Extracted 59 stat:  ['Zarrukh Adashev', 'Record: 4-4-0', 'The Lion', '5\' 5"', '125 lbs.', '65"', 'Southpaw', 'Jul 29, 1992', '3.65', '40%', '3.04', '64%', '0.00', '0%', '100%', '0.5']
# link:  http://ufcstats.com/fighter-details/1338e2c7480bdf9e
# Extracted 60 stat:  ['Israel Adesanya', 'Record: 24-5-0', 'The Last Stylebender', '6\' 4"', '185 lbs.', '80"', 'Switch', 'Jul 22, 1989', '4.02', '48%', '3.20', '55%', '0.05', '11%', '76%', '0.1']
# link:  http://ufcstats.com/fighter-details/1338e2c7480bdf9e
# Extracted 61 stat:  ['Israel Adesanya', 'Record: 24-5-0', 'The Last Stylebender', '6\' 4"', '185 lbs.', '80"', 'Switch', 'Jul 22, 1989', '4.02', '48%', '3.20', '55%', '0.05', '11%', '76%', '0.1']
# link:  http://ufcstats.com/fighter-details/1338e2c7480bdf9e
# Extracted 62 stat:  ['Israel Adesanya', 'Record: 24-5-0', 'The Last Stylebender', '6\' 4"', '185 lbs.', '80"', 'Switch', 'Jul 22, 1989', '4.02', '48%', '3.20', '55%', '0.05', '11%', '76%', '0.1']
# link:  http://ufcstats.com/fighter-details/0e9869d712e81f8f
# Extracted 63 stat:  ['Sam Adkins', 'Record: 7-20-2', 'The Experience', '6\' 3"', '225 lbs.', '--', 'Orthodox', 'Apr 26, 1965', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/0e9869d712e81f8f
# Extracted 64 stat:  ['Sam Adkins', 'Record: 7-20-2', 'The Experience', '6\' 3"', '225 lbs.', '--', 'Orthodox', 'Apr 26, 1965', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/0e9869d712e81f8f
# Extracted 65 stat:  ['Sam Adkins', 'Record: 7-20-2', 'The Experience', '6\' 3"', '225 lbs.', '--', 'Orthodox', 'Apr 26, 1965', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/7a846fcbf182a7c8
# Extracted 66 stat:  ['Mohamed Ado', 'Record: 5-1-0', '', '5\' 11"', '170 lbs.', '76"', 'Switch', 'May 03, 2000', '1.66', '83%', '0.33', '75%', '4.97', '50%', '50%', '5.0']
# link:  http://ufcstats.com/fighter-details/7a846fcbf182a7c8
# Extracted 67 stat:  ['Mohamed Ado', 'Record: 5-1-0', '', '5\' 11"', '170 lbs.', '76"', 'Switch', 'May 03, 2000', '1.66', '83%', '0.33', '75%', '4.97', '50%', '50%', '5.0']
# link:  http://ufcstats.com/fighter-details/7a846fcbf182a7c8
# Extracted 68 stat:  ['Mohamed Ado', 'Record: 5-1-0', '', '5\' 11"', '170 lbs.', '76"', 'Switch', 'May 03, 2000', '1.66', '83%', '0.33', '75%', '4.97', '50%', '50%', '5.0']
# link:  http://ufcstats.com/fighter-details/ebc5af72ad5a28cb
# Extracted 69 stat:  ['Nick Agallar', 'Record: 24-6-0', '', '5\' 8"', '155 lbs.', '--', 'Orthodox', 'Jan 13, 1979', '0.69', '11%', '4.56', '42%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/ebc5af72ad5a28cb
# Extracted 70 stat:  ['Nick Agallar', 'Record: 24-6-0', '', '5\' 8"', '155 lbs.', '--', 'Orthodox', 'Jan 13, 1979', '0.69', '11%', '4.56', '42%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/ebc5af72ad5a28cb
# Extracted 71 stat:  ['Nick Agallar', 'Record: 24-6-0', '', '5\' 8"', '155 lbs.', '--', 'Orthodox', 'Jan 13, 1979', '0.69', '11%', '4.56', '42%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/a08ddd04eaffd81d
# Extracted 72 stat:  ['Mariya Agapova', 'Record: 10-5-0', 'Money Mashka', '5\' 6"', '125 lbs.', '68"', 'Southpaw', 'Apr 07, 1997', '4.43', '54%', '3.62', '52%', '0.55', '66%', '45%', '0.8']
# link:  http://ufcstats.com/fighter-details/a08ddd04eaffd81d
# Extracted 73 stat:  ['Mariya Agapova', 'Record: 10-5-0', 'Money Mashka', '5\' 6"', '125 lbs.', '68"', 'Southpaw', 'Apr 07, 1997', '4.43', '54%', '3.62', '52%', '0.55', '66%', '45%', '0.8']
# link:  http://ufcstats.com/fighter-details/a08ddd04eaffd81d
# Extracted 74 stat:  ['Mariya Agapova', 'Record: 10-5-0', 'Money Mashka', '5\' 6"', '125 lbs.', '68"', 'Southpaw', 'Apr 07, 1997', '4.43', '54%', '3.62', '52%', '0.55', '66%', '45%', '0.8']

# %% [markdown]
# **Ejercicio 7 (1 punto)**. Ahora te toca crear un dataset, y guardarlo con el nombre `fighters.csv`

# %%
import pandas as pd
from pandas import DataFrame
#Primero creamos el DF
df_fighters = DataFrame(listOfLists, columns=['NAME', 'RECORD', 'NICKNAME', 'HEIGHT', 'WEIGHT', 'REACH', 'STANCE', 'DOB', 'SLpM', 'Str. Acc.', 'SApM', 'Str. Def.', 'TD Avg.', 'TD Acc.', 'TD Def.', 'Sub. Avg.'])
display(df_fighters)
# Out:
#               NAME          RECORD      NICKNAME  HEIGHT    WEIGHT REACH  \
# 0        Tom Aaron   Record: 5-3-0                    --  155 lbs.    --
# 1        Tom Aaron   Record: 5-3-0                    --  155 lbs.    --
# 2        Tom Aaron   Record: 5-3-0                    --  155 lbs.    --
# 3     Danny Abbadi   Record: 4-6-0  The Assassin  5' 11"  155 lbs.    --
# 4     Danny Abbadi   Record: 4-6-0  The Assassin  5' 11"  155 lbs.    --
# ..             ...             ...           ...     ...       ...   ...
# 70    Nick Agallar  Record: 24-6-0                 5' 8"  155 lbs.    --
# 71    Nick Agallar  Record: 24-6-0                 5' 8"  155 lbs.    --
# 72  Mariya Agapova  Record: 10-5-0  Money Mashka   5' 6"  125 lbs.   68"
# 73  Mariya Agapova  Record: 10-5-0  Money Mashka   5' 6"  125 lbs.   68"
# 74  Mariya Agapova  Record: 10-5-0  Money Mashka   5' 6"  125 lbs.   68"
#
#       STANCE           DOB  SLpM Str. Acc.  SApM Str. Def. TD Avg. TD Acc.  \
# 0             Jul 13, 1978  0.00        0%  0.00        0%    0.00      0%
# 1             Jul 13, 1978  0.00        0%  0.00        0%    0.00      0%
# 2             Jul 13, 1978  0.00        0%  0.00        0%    0.00      0%
# 3   Orthodox  Jul 03, 1983  3.29       38%  4.41       57%    0.00      0%
# 4   Orthodox  Jul 03, 1983  3.29       38%  4.41       57%    0.00      0%
# ..       ...           ...   ...       ...   ...       ...     ...     ...
# 70  Orthodox  Jan 13, 1979  0.69       11%  4.56       42%    0.00      0%
# 71  Orthodox  Jan 13, 1979  0.69       11%  4.56       42%    0.00      0%
# 72  Southpaw  Apr 07, 1997  4.43       54%  3.62       52%    0.55     66%
# 73  Southpaw  Apr 07, 1997  4.43       54%  3.62       52%    0.55     66%
# 74  Southpaw  Apr 07, 1997  4.43       54%  3.62       52%    0.55     66%
#
#    TD Def. Sub. Avg.
# 0       0%       0.0
# 1       0%       0.0
# 2       0%       0.0
# 3      77%       0.0
# 4      77%       0.0
# ..     ...       ...
# 70      0%       0.0
# 71      0%       0.0
# 72     45%       0.8
# 73     45%       0.8
# 74     45%       0.8
#
# [75 rows x 16 columns]

# %%
#Ahora lo guardamos
df_fighters.to_csv('fighters.csv', sep=',', index=False)
print("Archivo CSV 'df_fighters.csv' creado.")
# Out:
# Archivo CSV 'df_fighters.csv' creado.

# %% [markdown]
# **Ejercicio 8** (1 punto). Ahora, vamos a intentar crear un dataset con los luchadores más importantes. Para ello, accede a la página `http://ufcstats.com/statistics/fighters?char=a&page=all` y selecciona únicamente los campeones. Cabe destacar que los campeones son aquellos que tienen el icono de un cinturón <img src="http://1e49bc5171d173577ecd-1323f4090557a33db01577564f60846c.r80.cf1.rackcdn.com/belt.png" class="b-list__icon"> en la última celda

# %%
# Hemos hecho desde este ejercicio en adelante, también decirte que en el ejercicio 2 debimos quitar con Ctrl+Z en algún momento la línea

# basicStat = ""        de la función cleanBasicStat que imagino que te habrá dado error por ello.

# def cleanBasicStat(cadena):
#     basicStat = ""
#     if ":" in cadena:
#         basicStat = cadena.split(":")[1].strip()
#     return basicStat

# Y la otra diferencia de cosas anteriores es haber cambiado un print(df_fighters) por un display para que se vea mejor el DataFrame.

utlTops = "http://ufcstats.com/statistics/fighters?char=a&page=all"
page = requests.get(utlTops)
soup = BeautifulSoup(page.text, 'html.parser')

def extractTopFighterLinksList(soup):
    tabla = soup.find(class_="b-statistics__table")
    filas = tabla.find_all("tr", class_="b-statistics__table-row")
    
    nuevaLista = []
    for fila in filas:
        if fila.find("img", class_="b-list__icon"):
            link = fila.find(class_="b-link b-link_style_black")
            if link:
                nuevaLista.append(link.get("href"))
                
    return nuevaLista
                
topLinkList = extractTopFighterLinksList(soup)

topListFighters = extractFighterListOfLists(topLinkList)

df_top_fighters = DataFrame(topListFighters, columns=['NAME', 'RECORD', 'NICKNAME', 'HEIGHT', 'WEIGHT', 'REACH', 'STANCE', 'DOB', 'SLpM', 'Str. Acc.', 'SApM', 'Str. Def.', 'TD Avg.', 'TD Acc.', 'TD Def.', 'Sub. Avg.'])
display(df_top_fighters)
# Out:
# link:  http://ufcstats.com/fighter-details/399afbabc02376b5
# Extracted 0 stat:  ['Tom Aspinall', 'Record: 15-3-0 (1 NC)', '', '6\' 5"', '255 lbs.', '78"', 'Orthodox', 'Apr 11, 1993', '7.63', '67%', '3.62', '56%', '2.62', '80%', '100%', '1.3']
#            NAME                 RECORD NICKNAME HEIGHT    WEIGHT REACH  \
# 0  Tom Aspinall  Record: 15-3-0 (1 NC)           6' 5"  255 lbs.   78"
#
#      STANCE           DOB  SLpM Str. Acc.  SApM Str. Def. TD Avg. TD Acc.  \
# 0  Orthodox  Apr 11, 1993  7.63       67%  3.62       56%    2.62     80%
#
#   TD Def. Sub. Avg.
# 0    100%       1.3

# %% [markdown]
# **Ejercicio extra 1** Si ya has llegado hasta aqui, tienes que intentarlo, en el ejercicio anterior únicamente has obtenido los campeones que empiezan por la letra a. Obtiene todos los campeones de la 'a' a la 'z', modificando el caracter XX por una letra ``http://ufcstats.com/statistics/fighters?char=XX&page=all``

# %%
abecedario = "abcdefghijklmnopqrstuvwxyz"

champions = []
linkChampions = []

for letra in abecedario:
    url_letra = "http://ufcstats.com/statistics/fighters?char=" + letra + "&page=all"
    page = requests.get(url_letra)
    soup = BeautifulSoup(page.text, 'html.parser')
    
    links_tops = extractTopFighterLinksList(soup)
    
    for l in links_tops:
        if l not in linkChampions:
            linkChampions.append(l)
            
champions = extractFighterListOfLists(linkChampions)
# Out:
# link:  http://ufcstats.com/fighter-details/399afbabc02376b5
# Extracted 0 stat:  ['Tom Aspinall', 'Record: 15-3-0 (1 NC)', '', '6\' 5"', '255 lbs.', '78"', 'Orthodox', 'Apr 11, 1993', '7.63', '67%', '3.62', '56%', '2.62', '80%', '100%', '1.3']
# link:  http://ufcstats.com/fighter-details/767755fd74662dbf
# Extracted 1 stat:  ['Khamzat Chimaev', 'Record: 15-0-0', 'Borz', '6\' 2"', '185 lbs.', '75"', 'Orthodox', 'May 01, 1994', '4.04', '60%', '2.32', '43%', '5.29', '55%', '85%', '1.8']
# link:  http://ufcstats.com/fighter-details/7447e9f28508106a
# Extracted 2 stat:  ['Mackenzie Dern', 'Record: 16-5-0', '', '5\' 4"', '115 lbs.', '63"', 'Orthodox', 'Mar 24, 1993', '3.47', '41%', '3.93', '51%', '0.93', '18%', '37%', '1.1']
# link:  http://ufcstats.com/fighter-details/9e8f6c728eb01124
# Extracted 3 stat:  ['Justin Gaethje', 'Record: 27-5-0', 'The Highlight', '5\' 11"', '155 lbs.', '70"', 'Orthodox', 'Nov 14, 1988', '6.48', '58%', '7.05', '51%', '0.33', '40%', '74%', '0.0']
# link:  http://ufcstats.com/fighter-details/1af1170ed937cba7
# Extracted 4 stat:  ['Kayla Harrison', 'Record: 19-1-0', '', '5\' 8"', '135 lbs.', '66"', 'Southpaw', 'Jul 02, 1990', '4.29', '62%', '1.10', '66%', '2.84', '37%', '100%', '0.9']
# link:  http://ufcstats.com/fighter-details/275aca31f61ba28c
# Extracted 5 stat:  ['Islam Makhachev', 'Record: 28-1-0', '', '5\' 10"', '170 lbs.', '70"', 'Southpaw', 'Oct 27, 1991', '2.45', '58%', '1.45', '61%', '3.10', '56%', '91%', '1.0']
# link:  http://ufcstats.com/fighter-details/e5549c82bfb5582d
# Extracted 6 stat:  ['Alex Pereira', 'Record: 13-3-0', 'Poatan', '6\' 4"', '205 lbs.', '79"', 'Orthodox', 'Jul 07, 1987', '5.16', '62%', '3.50', '53%', '0.11', '50%', '79%', '0.2']
# link:  http://ufcstats.com/fighter-details/132deb59abae64b1
# Extracted 7 stat:  ['Valentina Shevchenko', 'Record: 26-4-1', 'Bullet', '5\' 5"', '125 lbs.', '66"', 'Southpaw', 'Mar 07, 1988', '3.04', '52%', '2.00', '63%', '2.65', '61%', '76%', '0.3']
# link:  http://ufcstats.com/fighter-details/54f64b5e283b0ce7
# Extracted 8 stat:  ['Ilia Topuria', 'Record: 17-0-0', 'El Matador', '5\' 7"', '155 lbs.', '69"', 'Orthodox', 'Jan 21, 1997', '4.81', '48%', '3.83', '64%', '1.96', '61%', '93%', '1.1']
# link:  http://ufcstats.com/fighter-details/17e97649403ba428
# Extracted 9 stat:  ['Joshua Van', 'Record: 16-2-0', 'The Fearless', '5\' 5"', '125 lbs.', '65"', 'Orthodox', 'Oct 10, 2001', '8.84', '56%', '6.39', '57%', '0.84', '63%', '81%', '0.0']
# link:  http://ufcstats.com/fighter-details/e1248941344b3288
# Extracted 10 stat:  ['Alexander Volkanovski', 'Record: 28-4-0', 'The Great', '5\' 6"', '145 lbs.', '71"', 'Orthodox', 'Sep 29, 1988', '5.99', '57%', '3.31', '58%', '1.63', '34%', '68%', '0.2']
# link:  http://ufcstats.com/fighter-details/d661ce4da776fc20
# Extracted 11 stat:  ['Petr Yan', 'Record: 20-5-0', 'No Mercy', '5\' 7"', '135 lbs.', '67"', 'Switch', 'Feb 11, 1993', '5.16', '54%', '4.24', '59%', '1.70', '49%', '86%', '0.1']

# %%
#Creamos el DF
df_champs = pd.DataFrame(champions, columns=['NAME', 'RECORD', 'NICKNAME', 'HEIGHT', 'WEIGHT', 'REACH', 'STANCE', 'DOB', 'SLpM', 'Str. Acc.', 'SApM', 'Str. Def.', 'TD Avg.', 'TD Acc.', 'TD Def.', 'Sub. Avg.'])
display(df_champs)
#Y lo guardamos
df_champs.to_csv('fighters_champs.csv', sep=',', index=False)
print("Archivo CSV 'df_champs.csv' creado.")
# Out:
#                      NAME                 RECORD       NICKNAME  HEIGHT  \
# 0            Tom Aspinall  Record: 15-3-0 (1 NC)                  6' 5"
# 1         Khamzat Chimaev         Record: 15-0-0           Borz   6' 2"
# 2          Mackenzie Dern         Record: 16-5-0                  5' 4"
# 3          Justin Gaethje         Record: 27-5-0  The Highlight  5' 11"
# 4          Kayla Harrison         Record: 19-1-0                  5' 8"
# 5         Islam Makhachev         Record: 28-1-0                 5' 10"
# 6            Alex Pereira         Record: 13-3-0         Poatan   6' 4"
# 7    Valentina Shevchenko         Record: 26-4-1         Bullet   5' 5"
# 8            Ilia Topuria         Record: 17-0-0     El Matador   5' 7"
# 9              Joshua Van         Record: 16-2-0   The Fearless   5' 5"
# 10  Alexander Volkanovski         Record: 28-4-0      The Great   5' 6"
# 11               Petr Yan         Record: 20-5-0       No Mercy   5' 7"
#
#       WEIGHT REACH    STANCE           DOB  SLpM Str. Acc.  SApM Str. Def.  \
# 0   255 lbs.   78"  Orthodox  Apr 11, 1993  7.63       67%  3.62       56%
# 1   185 lbs.   75"  Orthodox  May 01, 1994  4.04       60%  2.32       43%
# 2   115 lbs.   63"  Orthodox  Mar 24, 1993  3.47       41%  3.93       51%
# 3   155 lbs.   70"  Orthodox  Nov 14, 1988  6.48       58%  7.05       51%
# 4   135 lbs.   66"  Southpaw  Jul 02, 1990  4.29       62%  1.10       66%
# 5   170 lbs.   70"  Southpaw  Oct 27, 1991  2.45       58%  1.45       61%
# 6   205 lbs.   79"  Orthodox  Jul 07, 1987  5.16       62%  3.50       53%
# 7   125 lbs.   66"  Southpaw  Mar 07, 1988  3.04       52%  2.00       63%
# 8   155 lbs.   69"  Orthodox  Jan 21, 1997  4.81       48%  3.83       64%
# 9   125 lbs.   65"  Orthodox  Oct 10, 2001  8.84       56%  6.39       57%
# 10  145 lbs.   71"  Orthodox  Sep 29, 1988  5.99       57%  3.31       58%
# 11  135 lbs.   67"    Switch  Feb 11, 1993  5.16       54%  4.24       59%
#
#    TD Avg. TD Acc. TD Def. Sub. Avg.
# 0     2.62     80%    100%       1.3
# 1     5.29     55%     85%       1.8
# 2     0.93     18%     37%       1.1
# 3     0.33     40%     74%       0.0
# 4     2.84     37%    100%       0.9
# 5     3.10     56%     91%       1.0
# 6     0.11     50%     79%       0.2
# 7     2.65     61%     76%       0.3
# 8     1.96     61%     93%       1.1
# 9     0.84     63%     81%       0.0
# 10    1.63     34%     68%       0.2
# 11    1.70     49%     86%       0.1
# Archivo CSV 'df_champs.csv' creado.

# %% [markdown]
# **Ejercicio extra 2** Extrae todos los luchadores, no solo campeones

# %%
abecedario = "abcdefghijklmnopqrstuvwxyz"

fighters = []
linkFighters = []

for letra in abecedario:
    url_letra = "http://ufcstats.com/statistics/fighters?char=" + letra + "&page=all"
    page = requests.get(url_letra)
    soup = BeautifulSoup(page.text, 'html.parser')
    
    links_tops = extractFighterLinksList(soup)
    
    for l in links_tops:
        if l not in linkFighters:
            linkFighters.append(l)
            
fighters = extractFighterListOfLists(linkFighters)
    

print(fighters)


#Creamos el DF
df_fighters = pd.DataFrame(fighters, columns=['NAME', 'RECORD', 'NICKNAME', 'HEIGHT', 'WEIGHT', 'REACH', 'STANCE', 'DOB', 'SLpM', 'Str. Acc.', 'SApM', 'Str. Def.', 'TD Avg.', 'TD Acc.', 'TD Def.', 'Sub. Avg.'])
display(df_fighters)
#Y lo guardamos
df_fighters.to_csv('all_fighters.csv', sep=',', index=False)
print("Archivo CSV 'all_fighters.csv' creado.")
# Out:
# link:  http://ufcstats.com/fighter-details/93fe7332d16c6ad9
# Extracted 0 stat:  ['Tom Aaron', 'Record: 5-3-0', '', '--', '155 lbs.', '--', '', 'Jul 13, 1978', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/15df64c02b6b0fde
# Extracted 1 stat:  ['Danny Abbadi', 'Record: 4-6-0', 'The Assassin', '5\' 11"', '155 lbs.', '--', 'Orthodox', 'Jul 03, 1983', '3.29', '38%', '4.41', '57%', '0.00', '0%', '77%', '0.0']
# link:  http://ufcstats.com/fighter-details/59a9d6dac61c2540
# Extracted 2 stat:  ['Nariman Abbasov', 'Record: 28-4-0', 'Bayraktar', '5\' 8"', '155 lbs.', '66"', 'Orthodox', 'Feb 01, 1994', '3.00', '20%', '5.67', '46%', '0.00', '0%', '66%', '0.0']
# link:  http://ufcstats.com/fighter-details/4961467134abd8be
# Extracted 3 stat:  ['Darion Abbey', 'Record: 9-5-0', '', '6\' 2"', '265 lbs.', '80"', 'Orthodox', 'Feb 25, 1993', '8.44', '50%', '14.06', '28%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/b361180739bed4b0
# Extracted 4 stat:  ['David Abbott', 'Record: 10-15-0', 'Tank', '6\' 0"', '265 lbs.', '--', 'Switch', 'Apr 26, 1965', '1.35', '30%', '3.55', '38%', '1.07', '33%', '66%', '0.0']
# link:  http://ufcstats.com/fighter-details/3329d692aea4dc28
# Extracted 5 stat:  ['Hamdy Abdelwahab', 'Record: 7-1-0 (1 NC)', 'The Hammer', '6\' 2"', '265 lbs.', '72"', 'Southpaw', 'Jan 22, 1993', '4.27', '55%', '3.67', '51%', '3.25', '65%', '100%', '0.0']
# link:  http://ufcstats.com/fighter-details/841695e02c99a521
# Extracted 6 stat:  ['Mansur Abdul-Malik', 'Record: 9-0-1', '', '6\' 2"', '185 lbs.', '80"', 'Orthodox', 'Oct 07, 1997', '4.18', '48%', '3.46', '51%', '0.94', '50%', '83%', '0.5']
# link:  http://ufcstats.com/fighter-details/2f5cbecbbe18bac4
# Extracted 7 stat:  ['Shamil Abdurakhimov', 'Record: 20-8-0', 'Abrek', '6\' 3"', '235 lbs.', '76"', 'Orthodox', 'Sep 02, 1981', '2.41', '44%', '3.02', '55%', '1.01', '23%', '45%', '0.1']
# link:  http://ufcstats.com/fighter-details/c0ed7b208197e8de
# Extracted 8 stat:  ['Hiroyuki Abe', 'Record: 8-15-3 (1 NC)', 'Abe Ani', '5\' 6"', '145 lbs.', '--', 'Orthodox', 'Feb 09, 1970', '1.71', '36%', '3.11', '63%', '0.00', '0%', '33%', '0.0']
# link:  http://ufcstats.com/fighter-details/5140122c3eecd307
# Extracted 9 stat:  ['Daichi Abe', 'Record: 6-2-0', '', '5\' 11"', '170 lbs.', '71"', 'Orthodox', 'Nov 27, 1991', '3.80', '33%', '4.49', '56%', '0.33', '50%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/c9f6385af6df66d7
# Extracted 10 stat:  ['Papy Abedi', 'Record: 10-4-0', 'Makambo', '5\' 11"', '185 lbs.', '--', 'Southpaw', 'Jun 30, 1978', '2.80', '55%', '3.15', '48%', '3.47', '57%', '50%', '1.3']
# link:  http://ufcstats.com/fighter-details/aa6e591c2a2cdecd
# Extracted 11 stat:  ['Ricardo Abreu', 'Record: 5-1-0', 'Demente', '5\' 11"', '185 lbs.', '--', 'Orthodox', 'Apr 27, 1984', '3.79', '31%', '3.98', '68%', '2.13', '42%', '100%', '0.7']
# link:  http://ufcstats.com/fighter-details/7279654c7674cd24
# Extracted 12 stat:  ['Klidson Abreu', 'Record: 15-4-0 (1 NC)', 'White Bear', '6\' 0"', '205 lbs.', '74"', 'Orthodox', 'Dec 24, 1992', '2.05', '40%', '2.90', '55%', '0.64', '20%', '80%', '0.0']
# link:  http://ufcstats.com/fighter-details/f689bd7bbd14b392
# Extracted 13 stat:  ['Cyborg Abreu', 'Record: 0-0-0', '', '--', '--', '--', '', 'Dec 20, 1980', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/1c5879330d42255f
# Extracted 14 stat:  ['Daniel Acacio', 'Record: 30-18-0', '', '5\' 8"', '180 lbs.', '--', 'Orthodox', 'Dec 27, 1977', '3.52', '36%', '2.85', '62%', '0.33', '20%', '81%', '0.0']
# link:  http://ufcstats.com/fighter-details/989b85f6540c86b1
# Extracted 15 stat:  ['John Adajar', 'Record: 6-2-0', 'The Outlaw', '5\' 9"', '170 lbs.', '75"', 'Orthodox', 'Jun 22, 1991', '3.90', '52%', '6.28', '44%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/2620f3eb21c79614
# Extracted 16 stat:  ['Scott Adams', 'Record: 8-1-0', '', '6\' 0"', '225 lbs.', '--', 'Southpaw', '--', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/83b00f7597e5ac83
# Extracted 17 stat:  ['Juan Adams', 'Record: 5-3-0', 'The Kraken', '6\' 5"', '265 lbs.', '80"', 'Orthodox', 'Jan 16, 1992', '7.09', '55%', '4.06', '34%', '0.91', '66%', '57%', '0.0']
# link:  http://ufcstats.com/fighter-details/a77633a989013265
# Extracted 18 stat:  ['Anthony Adams', 'Record: 8-2-0', 'Sugafoot', '6\' 1"', '185 lbs.', '76"', 'Orthodox', 'Jan 13, 1988', '3.17', '41%', '5.93', '44%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/79cb2a690b9ba5e8
# Extracted 19 stat:  ['Zarrukh Adashev', 'Record: 4-4-0', 'The Lion', '5\' 5"', '125 lbs.', '65"', 'Southpaw', 'Jul 29, 1992', '3.65', '40%', '3.04', '64%', '0.00', '0%', '100%', '0.5']
# link:  http://ufcstats.com/fighter-details/1338e2c7480bdf9e
# Extracted 20 stat:  ['Israel Adesanya', 'Record: 24-5-0', 'The Last Stylebender', '6\' 4"', '185 lbs.', '80"', 'Switch', 'Jul 22, 1989', '4.02', '48%', '3.20', '55%', '0.05', '11%', '76%', '0.1']
# link:  http://ufcstats.com/fighter-details/0e9869d712e81f8f
# Extracted 21 stat:  ['Sam Adkins', 'Record: 7-20-2', 'The Experience', '6\' 3"', '225 lbs.', '--', 'Orthodox', 'Apr 26, 1965', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/7a846fcbf182a7c8
# Extracted 22 stat:  ['Mohamed Ado', 'Record: 5-1-0', '', '5\' 11"', '170 lbs.', '76"', 'Switch', 'May 03, 2000', '1.66', '83%', '0.33', '75%', '4.97', '50%', '50%', '5.0']
# link:  http://ufcstats.com/fighter-details/ebc5af72ad5a28cb
# Extracted 23 stat:  ['Nick Agallar', 'Record: 24-6-0', '', '5\' 8"', '155 lbs.', '--', 'Orthodox', 'Jan 13, 1979', '0.69', '11%', '4.56', '42%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/a08ddd04eaffd81d
# Extracted 24 stat:  ['Mariya Agapova', 'Record: 10-5-0', 'Money Mashka', '5\' 6"', '125 lbs.', '68"', 'Southpaw', 'Apr 07, 1997', '4.43', '54%', '3.62', '52%', '0.55', '66%', '45%', '0.8']
# link:  http://ufcstats.com/fighter-details/26f4288e83188c61
# Extracted 25 stat:  ['Kantharaj Agasa', 'Record: 12-3-0', 'Kannadiga', '--', '135 lbs.', '--', '', 'Feb 16, 1992', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/44aa652b181bcf68
# Extracted 26 stat:  ['Marcelo Aguiar', 'Record: 2-3-1', '', '5\' 10"', '170 lbs.', '--', 'Orthodox', 'Jan 20, 1969', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/501821d7fb7b95c1
# Extracted 27 stat:  ['Fabio Aguiar', 'Record: 17-1-0', '', '6\' 0"', '185 lbs.', '--', '', 'Feb 10, 1988', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/6cadc0a0ba7dc015
# Extracted 28 stat:  ['Edwin Aguilar', 'Record: 26-19-0 (1 NC)', 'Tigre', '5\' 10"', '185 lbs.', '--', '', 'Jan 01, 1972', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/8f382b3baa954d2a
# Extracted 29 stat:  ['Jessica Aguilar', 'Record: 20-8-0', 'Jag', '5\' 3"', '115 lbs.', '63"', 'Orthodox', 'May 08, 1982', '4.93', '50%', '7.19', '53%', '0.94', '25%', '50%', '0.2']
# link:  http://ufcstats.com/fighter-details/cf946e03ba2e7666
# Extracted 30 stat:  ['Kevin Aguilar', 'Record: 17-5-0', 'Angel of Death', '5\' 7"', '155 lbs.', '73"', 'Orthodox', 'Sep 07, 1988', '3.96', '40%', '4.81', '52%', '0.16', '16%', '78%', '0.0']
# link:  http://ufcstats.com/fighter-details/c051c2e12d692b8a
# Extracted 31 stat:  ['Jesus Aguilar', 'Record: 12-3-0', '', '5\' 4"', '125 lbs.', '62"', 'Orthodox', 'Mar 13, 1996', '2.65', '40%', '1.85', '62%', '1.64', '31%', '48%', '1.4']
# link:  http://ufcstats.com/fighter-details/ae071698e1a3ccd4
# Extracted 32 stat:  ['Christian Aguilera', 'Record: 14-8-0', 'The Beast', '5\' 9"', '170 lbs.', '72"', 'Switch', 'Nov 25, 1991', '2.54', '37%', '4.04', '48%', '0.00', '0%', '60%', '0.0']
# link:  http://ufcstats.com/fighter-details/0978385b2bd9ef9b
# Extracted 33 stat:  ['Nick Aguirre', 'Record: 7-2-0', 'Slick', '5\' 9"', '135 lbs.', '74"', 'Southpaw', 'Jan 15, 1996', '0.73', '33%', '2.89', '45%', '1.16', '20%', '33%', '0.6']
# link:  http://ufcstats.com/fighter-details/b2efa582adf73604
# Extracted 34 stat:  ['Agulali', 'Record: 13-2-0', '', '5\' 9"', '125 lbs.', '67"', 'Switch', 'Apr 07, 2005', '2.74', '60%', '2.19', '59%', '0.00', '0%', '100%', '0.0']
# link:  http://ufcstats.com/fighter-details/ff584c17bccbae0b
# Extracted 35 stat:  ['Ahejiang Ailinuer', 'Record: 15-3-0', '', '--', '145 lbs.', '--', '', '--', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/9e3dbb9c68ed5d1a
# Extracted 36 stat:  ['Mike Aina', 'Record: 14-6-1 (1 NC)', 'Iron', '5\' 9"', '155 lbs.', '--', 'Orthodox', 'Dec 25, 1980', '2.87', '33%', '6.33', '59%', '0.00', '0%', '71%', '0.0']
# link:  http://ufcstats.com/fighter-details/49dea784f6cfed71
# Extracted 37 stat:  ['Ashiek Ajim', 'Record: 6-2-0', 'Peak Physique', '5\' 8"', '135 lbs.', '71"', 'Switch', 'Jun 19, 1994', '5.00', '40%', '11.25', '25%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/2eada40ac8801559
# Extracted 38 stat:  ['Hitomi Akano', 'Record: 18-10-0', 'Girlfight Monster', '5\' 4"', '135 lbs.', '--', 'Southpaw', 'Jul 27, 1974', '0.59', '45%', '2.58', '55%', '0.00', '0%', '8%', '0.5']
# link:  http://ufcstats.com/fighter-details/16690d100f995f8f
# Extracted 39 stat:  ['Omari Akhmedov', 'Record: 21-6-1', 'Wolverine', '6\' 0"', '185 lbs.', '73"', 'Orthodox', 'Oct 12, 1987', '2.97', '34%', '2.84', '55%', '2.58', '45%', '65%', '0.2']
# link:  http://ufcstats.com/fighter-details/b0550072e5f0afa7
# Extracted 40 stat:  ['Yoshihiro Akiyama', 'Record: 14-6-0 (2 NC)', '', '5\' 10"', '170 lbs.', '75"', 'Orthodox', 'Jul 29, 1975', '3.10', '41%', '3.62', '57%', '2.29', '67%', '92%', '1.0']
# link:  http://ufcstats.com/fighter-details/1fc64507a0cb38cf
# Extracted 41 stat:  ['Rostem Akman', 'Record: 6-2-0', '', '5\' 10"', '170 lbs.', '72"', 'Switch', 'Dec 19, 1991', '1.80', '25%', '3.97', '57%', '1.00', '40%', '87%', '0.0']
# link:  http://ufcstats.com/fighter-details/38b50fd1e1b5b656
# Extracted 42 stat:  ['Razak Al-Hassan', 'Record: 13-5-0', '', '6\' 2"', '205 lbs.', '--', 'Orthodox', 'May 14, 1982', '3.27', '39%', '3.14', '60%', '0.65', '14%', '57%', '0.0']
# link:  http://ufcstats.com/fighter-details/597499ac7a5aac62
# Extracted 43 stat:  ['Abdul-Kareem Al-Selwady', 'Record: 15-4-0', 'Pride of Palestine', '5\' 8"', '155 lbs.', '69"', 'Orthodox', 'Apr 10, 1995', '4.14', '34%', '3.60', '59%', '2.32', '30%', '20%', '0.0']
# link:  http://ufcstats.com/fighter-details/1cf1310684a841f5
# Extracted 44 stat:  ['Mostapha Al-Turk', 'Record: 6-6-0', '', '6\' 2"', '245 lbs.', '77"', 'Orthodox', 'Jul 14, 1973', '1.36', '19%', '3.61', '53%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/7578cc6bd750206b
# Extracted 45 stat:  ['Herdem Alacabek', 'Record: 5-1-0', '', '6\' 2"', '205 lbs.', '75"', 'Orthodox', 'Jun 07, 1991', '3.84', '65%', '6.66', '23%', '2.06', '50%', '42%', '0.0']
# link:  http://ufcstats.com/fighter-details/2144954270be834d
# Extracted 46 stat:  ['Javi Alanis', 'Record: 0-4-0', '', '5\' 6"', '135 lbs.', '--', '', '--', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/1897b7b913736a7c
# Extracted 47 stat:  ['Alatengheili', 'Record: 17-10-2', 'The Mongolian Knight', '5\' 5"', '135 lbs.', '66"', 'Orthodox', 'Dec 14, 1991', '2.82', '32%', '5.12', '57%', '1.74', '43%', '75%', '0.0']
# link:  http://ufcstats.com/fighter-details/6d35bf94f7d30241
# Extracted 48 stat:  ['Amir Albazi', 'Record: 17-3-0', 'The Prince', '5\' 5"', '125 lbs.', '68"', 'Orthodox', 'Oct 27, 1993', '2.47', '33%', '3.88', '59%', '1.18', '25%', '62%', '0.4']
# link:  http://ufcstats.com/fighter-details/9b28292abe3166d5
# Extracted 49 stat:  ['Brett Albee', 'Record: 3-2-0', '', '--', '225 lbs.', '--', '', '--', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/7bd94b60d7521e4a
# Extracted 50 stat:  ['John Albert', 'Record: 6-5-0', 'Prince', '5\' 8"', '135 lbs.', '68"', 'Orthodox', 'Oct 13, 1986', '3.05', '49%', '2.82', '35%', '0.00', '0%', '50%', '6.1']
# link:  http://ufcstats.com/fighter-details/c482c8605455a213
# Extracted 51 stat:  ['Junior Albini', 'Record: 14-6-0', 'Baby', '6\' 3"', '264 lbs.', '74"', 'Orthodox', 'Mar 15, 1991', '3.98', '51%', '6.08', '52%', '1.54', '37%', '100%', '0.0']
# link:  http://ufcstats.com/fighter-details/184b955181bdef52
# Extracted 52 stat:  ['Wes Albritton', 'Record: 0-1-0', '', '5\' 10"', '188 lbs.', '--', 'Orthodox', '--', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/e76d9f656ceb82ab
# Extracted 53 stat:  ['Aleksandra Albu', 'Record: 3-2-0', 'Stitch', '5\' 2"', '115 lbs.', '63"', 'Orthodox', 'Jul 14, 1990', '4.83', '47%', '5.56', '38%', '2.27', '50%', '77%', '0.4']
# link:  http://ufcstats.com/fighter-details/dd1b90eea08887f6
# Extracted 54 stat:  ['Israel Albuquerque', 'Record: 0-3-0', '', '--', '185 lbs.', '--', 'Orthodox', '--', '0.32', '13%', '3.34', '25%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/39f62b833e4cf126
# Extracted 55 stat:  ['Juan Alcain', 'Record: 1-2-0', '', '--', '--', '--', '', '--', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/2f95a3c6d58b2aad
# Extracted 56 stat:  ['Iuri Alcantara', 'Record: 35-10-0 (1 NC)', 'Marajo', '5\' 9"', '135 lbs.', '71"', 'Southpaw', 'Aug 04, 1980', '2.72', '45%', '2.79', '49%', '1.44', '62%', '60%', '0.8']
# link:  http://ufcstats.com/fighter-details/7c6e87729e824ef4
# Extracted 57 stat:  ['Ildemar Alcantara', 'Record: 21-11-0', 'Marajo', '6\' 2"', '185 lbs.', '78"', 'Orthodox', 'Nov 18, 1982', '1.93', '38%', '2.63', '50%', '2.00', '68%', '81%', '0.9']
# link:  http://ufcstats.com/fighter-details/1e38bba6738b7b10
# Extracted 58 stat:  ['Alfonso Alcarez', 'Record: 1-3-1', '', '5\' 3"', '145 lbs.', '--', '', 'Jun 10, 1970', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/d26934530dc5b248
# Extracted 59 stat:  ['Gilbert Aldana', 'Record: 6-2-0', 'El Peligro', '6\' 1"', '250 lbs.', '--', 'Orthodox', 'Aug 25, 1977', '2.91', '54%', '6.26', '26%', '2.57', '40%', '33%', '0.0']
# link:  http://ufcstats.com/fighter-details/578ef12674df1e6a
# Extracted 60 stat:  ['Irene Aldana', 'Record: 15-8-0', '', '5\' 9"', '135 lbs.', '68"', 'Orthodox', 'Mar 26, 1988', '5.19', '39%', '6.64', '56%', '0.15', '50%', '77%', '0.2']
# link:  http://ufcstats.com/fighter-details/c487223b0289bda9
# Extracted 61 stat:  ['Hector Aldana', 'Record: 4-3-0', '', '5\' 11"', '170 lbs.', '72"', 'Orthodox', 'Aug 17, 1988', '3.59', '38%', '5.08', '59%', '0.93', '100%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/7460ddef986d3144
# Extracted 62 stat:  ['Jose Alday', 'Record: 14-6-1', 'Pochito', '5\' 7"', '135 lbs.', '68"', 'Orthodox', 'Sep 14, 1991', '3.13', '44%', '3.13', '58%', '0.00', '0%', '57%', '0.0']
# link:  http://ufcstats.com/fighter-details/d0f3959b4a9747e6
# Extracted 63 stat:  ['Jose Aldo', 'Record: 32-10-0', '', '5\' 7"', '135 lbs.', '70"', 'Orthodox', 'Sep 09, 1986', '3.65', '46%', '3.81', '60%', '0.47', '51%', '92%', '0.1']
# link:  http://ufcstats.com/fighter-details/6fd953151d981979
# Extracted 64 stat:  ['JJ Aldrich', 'Record: 14-7-0', '', '5\' 5"', '125 lbs.', '67"', 'Southpaw', 'Sep 29, 1992', '3.96', '47%', '4.32', '61%', '0.75', '26%', '67%', '0.0']
# link:  http://ufcstats.com/fighter-details/103e2e33a60683e1
# Extracted 65 stat:  ['Irina Alekseeva', 'Record: 5-4-0', 'Russian Ronda', '5\' 8"', '135 lbs.', '67"', 'Orthodox', 'Jun 27, 1990', '3.42', '38%', '5.02', '45%', '0.38', '20%', '50%', '0.4']
# link:  http://ufcstats.com/fighter-details/d35298b6df168456
# Extracted 66 stat:  ['Talita Alencar', 'Record: 7-1-1', 'Problem Child', '5\' 1"', '115 lbs.', '58"', 'Orthodox', 'Oct 17, 1990', '2.91', '37%', '3.36', '55%', '3.02', '26%', '66%', '0.6']
# link:  http://ufcstats.com/fighter-details/fe5a9547479396ab
# Extracted 67 stat:  ['Jim Alers', 'Record: 13-3-0 (1 NC)', 'The Beast', '5\' 9"', '145 lbs.', '71"', 'Orthodox', 'Oct 14, 1986', '2.90', '40%', '4.38', '56%', '2.26', '41%', '80%', '0.3']
# link:  http://ufcstats.com/fighter-details/7a15f3694c5cbc02
# Extracted 68 stat:  ['John Alessio', 'Record: 35-17-0 (2 NC)', 'The Natural', '5\' 10"', '155 lbs.', '72"', 'Orthodox', 'Jul 05, 1979', '2.10', '39%', '2.91', '54%', '1.85', '38%', '70%', '1.2']
# link:  http://ufcstats.com/fighter-details/0541480fbf719d86
# Extracted 69 stat:  ['Houston Alexander', 'Record: 17-15-1 (2 NC)', 'The Assassin', '6\' 0"', '205 lbs.', '72"', 'Orthodox', 'Mar 22, 1972', '3.06', '54%', '3.20', '52%', '1.19', '57%', '33%', '0.0']
# link:  http://ufcstats.com/fighter-details/8fd76e1b49c00ae2
# Extracted 70 stat:  ['Kenneth Alexander', 'Record: 7-6-0 (1 NC)', 'The Machine', '5\' 9"', '155 lbs.', '--', 'Orthodox', 'Sep 25, 1977', '0.88', '19%', '2.20', '66%', '4.71', '26%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/11583163f45c7b31
# Extracted 71 stat:  ['Lucas Alexander', 'Record: 8-5-0', 'The Lion', '5\' 11"', '145 lbs.', '73"', 'Orthodox', 'Jul 28, 1995', '4.69', '57%', '2.87', '56%', '0.00', '0%', '60%', '0.0']
# link:  http://ufcstats.com/fighter-details/d53482bef23235ba
# Extracted 72 stat:  ['Marcio Alexandre Junior', 'Record: 17-4-0', 'Lyoto', '6\' 0"', '185 lbs.', '75"', 'Southpaw', 'May 05, 1989', '1.61', '45%', '2.89', '42%', '0.35', '20%', '66%', '0.7']
# link:  http://ufcstats.com/fighter-details/b757c73f443d4fca
# Extracted 73 stat:  ['Olaf Alfonso', 'Record: 8-12-0', '', '6\' 2"', '170 lbs.', '--', 'Orthodox', 'Aug 06, 1974', '1.65', '38%', '4.77', '53%', '0.37', '7%', '22%', '0.7']
# link:  http://ufcstats.com/fighter-details/4b37a0bc2ab4cae1
# Extracted 74 stat:  ['Pablo Alfonso', 'Record: 9-7-0', 'The Hurricane', '5\' 8"', '145 lbs.', '--', '', 'May 09, 1983', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/41b34b7f11f6d085
# Extracted 75 stat:  ['Levi Alford', 'Record: 1-7-0', '', '--', '--', '--', '', '--', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/9abc648e76c4493a
# Extracted 76 stat:  ['Bill Algeo', 'Record: 18-9-0', 'Senor Perfecto', '6\' 0"', '145 lbs.', '73"', 'Switch', 'Jun 09, 1989', '5.88', '51%', '4.38', '47%', '1.03', '50%', '55%', '0.1']
# link:  http://ufcstats.com/fighter-details/669a3cb6e394f515
# Extracted 77 stat:  ['Royce Alger', 'Record: 3-2-0', '', '5\' 10"', '199 lbs.', '--', 'Orthodox', 'Mar 06, 1965', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/e17770faae3ca54c
# Extracted 78 stat:  ['Amir Aliakbari', 'Record: 10-1-0', '', '6\' 3"', '250 lbs.', '--', '', 'Jun 10, 1984', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/e70de1859b7ee78e
# Extracted 79 stat:  ['Sultan Aliev', 'Record: 15-3-0', '', '5\' 11"', '170 lbs.', '74"', 'Orthodox', 'Sep 17, 1984', '1.41', '45%', '2.20', '56%', '1.76', '38%', '100%', '0.0']
# link:  http://ufcstats.com/fighter-details/ca28cdf526d6b6e9
# Extracted 80 stat:  ['Nurullo Aliev', 'Record: 11-0-0', 'Tajik Eagle', '5\' 10"', '155 lbs.', '72"', 'Orthodox', 'Dec 08, 2000', '2.72', '44%', '1.63', '58%', '2.12', '43%', '80%', '0.3']
# link:  http://ufcstats.com/fighter-details/b07aed698fba8624
# Extracted 81 stat:  ['Ikram Aliskerov', 'Record: 17-2-0', '', '6\' 0"', '185 lbs.', '76"', 'Southpaw', 'Dec 07, 1992', '6.86', '64%', '5.47', '41%', '3.20', '60%', '100%', '0.5']
# link:  http://ufcstats.com/fighter-details/6db394bf6c3b017c
# Extracted 82 stat:  ['Leon Aliu', 'Record: 10-2-0', 'The Albanian Lion', '6\' 0"', '185 lbs.', '74"', 'Orthodox', 'Jul 14, 1989', '6.32', '50%', '10.11', '38%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/6ebe96a116e79e52
# Extracted 83 stat:  ['John Allan', 'Record: 13-7-0 (1 NC)', '', '6\' 1"', '205 lbs.', '75"', 'Orthodox', 'Feb 22, 1993', '3.56', '42%', '5.74', '52%', '1.40', '71%', '50%', '0.8']
# link:  http://ufcstats.com/fighter-details/1e13936d708bcff7
# Extracted 84 stat:  ['George Allen', 'Record: 13-19-2', '', '6\' 2"', '205 lbs.', '--', 'Open Stance', 'Jan 13, 1967', '0.80', '38%', '3.10', '43%', '0.00', '0%', '50%', '0.0']
# link:  http://ufcstats.com/fighter-details/040a74bb0a465c54
# Extracted 85 stat:  ['Arnold Allen', 'Record: 20-4-0', 'Almighty', '5\' 8"', '145 lbs.', '70"', 'Southpaw', 'Jan 22, 1994', '3.47', '42%', '3.04', '60%', '0.86', '47%', '71%', '0.3']
# link:  http://ufcstats.com/fighter-details/2f181c0467965b98
# Extracted 86 stat:  ['Brendan Allen', 'Record: 26-7-0', 'All In', '6\' 2"', '185 lbs.', '75"', 'Orthodox', 'Dec 28, 1995', '3.59', '53%', '3.62', '47%', '1.56', '42%', '56%', '1.1']
# link:  http://ufcstats.com/fighter-details/adf9a901308fb8e3
# Extracted 87 stat:  ['Daniel Allen', 'Record: 5-0-0', '', '6\' 0"', '155 lbs.', '75"', 'Southpaw', 'Aug 10, 1992', '7.60', '51%', '5.87', '53%', '2.00', '66%', '100%', '0.0']
# link:  http://ufcstats.com/fighter-details/c4fe2e9a06ea5bcb
# Extracted 88 stat:  ['Ben Alloway', 'Record: 18-8-0', 'Blanco', '5\' 11"', '170 lbs.', '76"', 'Orthodox', 'Feb 19, 1981', '1.28', '49%', '1.90', '59%', '0.62', '50%', '26%', '0.0']
# link:  http://ufcstats.com/fighter-details/8d3273573b85be09
# Extracted 89 stat:  ['Asu Almabayev', 'Record: 23-3-0', 'Zulfikar', '5\' 4"', '125 lbs.', '65"', 'Orthodox', 'Jan 25, 1994', '2.31', '50%', '1.99', '53%', '4.46', '42%', '44%', '1.5']
# link:  http://ufcstats.com/fighter-details/a4dc0f2b95df4cc1
# Extracted 90 stat:  ['Bekzat Almakhan', 'Record: 12-3-0', 'The Turan Warrior', '5\' 7"', '135 lbs.', '68"', 'Orthodox', 'Oct 08, 1997', '1.61', '34%', '3.73', '36%', '0.00', '0%', '41%', '0.0']
# link:  http://ufcstats.com/fighter-details/088aa1b19b2dc14a
# Extracted 91 stat:  ['John Dave Almanza', 'Record: 6-1-0', 'The Striker', '5\' 7"', '125 lbs.', '67"', 'Southpaw', 'Mar 22, 2004', '1.92', '41%', '5.75', '27%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/91186547a7f3f758
# Extracted 92 stat:  ['Ricardo Almeida', 'Record: 13-5-0', 'Big Dog', '6\' 0"', '170 lbs.', '74"', 'Orthodox', 'Nov 29, 1976', '2.02', '49%', '1.20', '61%', '3.74', '38%', '31%', '1.2']
# link:  http://ufcstats.com/fighter-details/d615d6a10a4704cd
# Extracted 93 stat:  ['Magno Almeida', 'Record: 10-3-0 (1 NC)', '', '6\' 0"', '155 lbs.', '--', '', 'Jun 06, 1985', '1.67', '36%', '2.60', '41%', '0.00', '0%', '40%', '5.0']
# link:  http://ufcstats.com/fighter-details/2b074403b7c6cdb4
# Extracted 94 stat:  ['Thomas Almeida', 'Record: 22-5-0', 'Thominhas', '5\' 7"', '145 lbs.', '70"', 'Southpaw', 'Jul 31, 1991', '4.84', '43%', '4.93', '61%', '0.17', '14%', '75%', '0.0']
# link:  http://ufcstats.com/fighter-details/67a992d4cff22466
# Extracted 95 stat:  ['Ericka Almeida', 'Record: 7-3-0', '', '5\' 6"', '115 lbs.', '--', 'Orthodox', 'Mar 05, 1989', '1.07', '39%', '3.33', '43%', '0.50', '33%', '37%', '0.0']
# link:  http://ufcstats.com/fighter-details/f16ddfa31236efed
# Extracted 96 stat:  ['Estefani Almeida', 'Record: 7-3-0', '', '5\' 4"', '125 lbs.', '--', 'Orthodox', 'Oct 17, 1988', '3.13', '37%', '6.07', '42%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/41e83a89929d1327
# Extracted 97 stat:  ['Jailton Almeida', 'Record: 22-5-0', 'Malhadinho', '6\' 3"', '225 lbs.', '79"', 'Orthodox', 'Jun 26, 1991', '2.23', '62%', '1.30', '43%', '5.64', '55%', '60%', '1.7']
# link:  http://ufcstats.com/fighter-details/710f0f8c5d5c9d41
# Extracted 98 stat:  ['Lucas Almeida', 'Record: 15-5-0', '', '5\' 11"', '145 lbs.', '71"', 'Orthodox', 'Jan 31, 1991', '4.94', '39%', '5.36', '44%', '0.00', '0%', '53%', '0.0']
# link:  http://ufcstats.com/fighter-details/64d47ef881a437a4
# Extracted 99 stat:  ['Cesar Almeida', 'Record: 7-2-0', 'Cesinha', '6\' 1"', '185 lbs.', '74"', 'Orthodox', 'Mar 28, 1988', '3.46', '58%', '2.03', '46%', '0.00', '0%', '52%', '0.2']
# link:  http://ufcstats.com/fighter-details/c6bf75775b278ed8
# Extracted 100 stat:  ['Mauricio Alonso', 'Record: 13-7-0 (1 NC)', '', '6\' 2"', '170 lbs.', '--', '', 'Feb 27, 1980', '5.74', '34%', '1.91', '67%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/49b130de1da2e1bf
# Extracted 101 stat:  ['Sarah Alpar', 'Record: 9-6-0', 'Too Sweet', '5\' 4"', '135 lbs.', '63"', 'Southpaw', 'Jun 01, 1991', '2.36', '44%', '6.06', '38%', '1.61', '26%', '20%', '0.4']
# link:  http://ufcstats.com/fighter-details/e87a13e02c01331d
# Extracted 102 stat:  ['Ali AlQaisi', 'Record: 8-5-0', 'The Royal Fighter', '5\' 6"', '135 lbs.', '68"', 'Orthodox', 'Sep 23, 1990', '2.43', '42%', '1.97', '56%', '3.50', '29%', '60%', '1.0']
# link:  http://ufcstats.com/fighter-details/c61b49cec6abd6b9
# Extracted 103 stat:  ['Rico Altamirano', 'Record: 4-3-0', '', '5\' 10"', '170 lbs.', '--', '', '--', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/dc7927cd622676a7
# Extracted 104 stat:  ['Victor Altamirano', 'Record: 12-5-0', 'El Magnifico', '5\' 8"', '125 lbs.', '70"', 'Switch', 'Jan 23, 1991', '4.58', '53%', '3.82', '53%', '2.88', '38%', '63%', '0.0']
# link:  http://ufcstats.com/fighter-details/c11036da9162cb5f
# Extracted 105 stat:  ['Mike Altman', 'Record: 1-4-0', '', '5\' 10"', '185 lbs.', '--', 'Orthodox', '--', '1.56', '20%', '2.08', '75%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/430c533614d45813
# Extracted 106 stat:  ['Patricia Alujas', 'Record: 9-3-0', 'The Angel', '5\' 4"', '115 lbs.', '64"', 'Orthodox', 'May 08, 1996', '5.83', '31%', '9.25', '44%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/e741536153227386
# Extracted 107 stat:  ['Sean Alvarez', 'Record: 4-3-0', '', '6\' 0"', '235 lbs.', '--', 'Orthodox', 'Jul 14, 1971', '0.89', '37%', '3.25', '47%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/33a331684283900f
# Extracted 108 stat:  ['Eddie Alvarez', 'Record: 29-6-0 (1 NC)', '', '5\' 9"', '155 lbs.', '69"', 'Orthodox', 'Jan 11, 1984', '4.32', '41%', '4.39', '55%', '2.92', '36%', '92%', '0.5']
# link:  http://ufcstats.com/fighter-details/4438482bd1d5a029
# Extracted 109 stat:  ['Jaime Alvarez', 'Record: 6-1-0', '', '5\' 8"', '125 lbs.', '69"', 'Orthodox', 'Mar 08, 1988', '2.73', '40%', '4.53', '56%', '1.00', '33%', '50%', '0.0']
# link:  http://ufcstats.com/fighter-details/58bbef3770bb2dfc
# Extracted 110 stat:  ['Joel Alvarez', 'Record: 23-3-0', 'El Fenomeno', '6\' 3"', '155 lbs.', '77"', 'Orthodox', 'Mar 02, 1993', '4.78', '55%', '3.07', '54%', '0.19', '33%', '47%', '1.1']
# link:  http://ufcstats.com/fighter-details/31ee470ef5dc8d7f
# Extracted 111 stat:  ['Thiago Alves', 'Record: 23-15-0', 'Pitbull', '5\' 9"', '170 lbs.', '70"', 'Orthodox', 'Oct 03, 1983', '3.73', '41%', '3.42', '62%', '0.71', '60%', '63%', '0.3']
# link:  http://ufcstats.com/fighter-details/bd92cf5da5413d2a
# Extracted 112 stat:  ['Anthony Alves', 'Record: 1-4-0', '', '--', '--', '--', '', '--', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/dc5a6b2fdb27e7dc
# Extracted 113 stat:  ['Amilcar Alves', 'Record: 15-12-0', '', '6\' 0"', '170 lbs.', '--', 'Southpaw', 'Aug 08, 1988', '0.50', '46%', '2.02', '30%', '0.00', '0%', '53%', '0.0']
# link:  http://ufcstats.com/fighter-details/d317a5e2b3f88c5f
# Extracted 114 stat:  ['Warlley Alves', 'Record: 15-8-0', '', '5\' 11"', '185 lbs.', '72"', 'Orthodox', 'Jan 04, 1991', '3.04', '48%', '3.95', '50%', '1.22', '50%', '62%', '0.8']
# link:  http://ufcstats.com/fighter-details/029afd138865d20a
# Extracted 115 stat:  ['Rafael Alves', 'Record: 20-12-0', 'The Turn', '5\' 8"', '155 lbs.', '68"', 'Orthodox', 'Nov 14, 1990', '1.85', '48%', '3.30', '58%', '0.29', '25%', '44%', '1.5']
# link:  http://ufcstats.com/fighter-details/d156513a19acf856
# Extracted 116 stat:  ['Sam Alvey', 'Record: 33-18-1 (1 NC)', "Smile'N", '6\' 2"', '185 lbs.', '75"', 'Southpaw', 'May 06, 1986', '3.28', '44%', '3.63', '52%', '0.06', '14%', '82%', '0.1']
# link:  http://ufcstats.com/fighter-details/f4abf9aeda861283
# Extracted 117 stat:  ['Christopher Alvidrez', 'Record: 7-1-0', 'The Newborn', '6\' 0"', '170 lbs.', '74"', 'Orthodox', 'Dec 27, 1996', '6.97', '62%', '2.11', '50%', '0.00', '0%', '100%', '0.0']
# link:  http://ufcstats.com/fighter-details/86c1441676af2c73
# Extracted 118 stat:  ['Mahamed Aly', 'Record: 4-1-0', '', '6\' 2"', '205 lbs.', '78"', 'Orthodox', 'Jan 11, 1994', '6.00', '66%', '12.00', '33%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/20821819c401ced8
# Extracted 119 stat:  ['Andre Amado', 'Record: 6-4-1', 'Dida', '6\' 0"', '154 lbs.', '--', 'Orthodox', 'Oct 09, 1983', '2.27', '24%', '5.91', '63%', '0.00', '0%', '20%', '0.0']
# link:  http://ufcstats.com/fighter-details/1e327b281ef6a745
# Extracted 120 stat:  ['Adlan Amagov', 'Record: 14-2-1', 'Borz', '6\' 2"', '170 lbs.', '76"', 'Orthodox', 'Oct 30, 1986', '3.29', '47%', '0.82', '78%', '5.84', '56%', '100%', '0.0']
# link:  http://ufcstats.com/fighter-details/247fbbfafea60bb1
# Extracted 121 stat:  ['Maiara Amanajas dos Santos', 'Record: 7-3-0', '', '5\' 5"', '115 lbs.', '--', 'Southpaw', 'Jul 11, 1987', '5.53', '35%', '24.47', '33%', '0.00', '0%', '100%', '0.0']
# link:  http://ufcstats.com/fighter-details/ee0b69e307c857e5
# Extracted 122 stat:  ['Chris Amarante', 'Record: 2-0-0', '', '--', '185 lbs.', '--', '', '--', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/c912f676692c353a
# Extracted 123 stat:  ['Jimmy Ambriz', 'Record: 17-21-1', 'The Titan', '6\' 2"', '315 lbs.', '--', 'Southpaw', 'Jan 26, 1970', '0.83', '29%', '3.76', '40%', '3.13', '57%', '100%', '0.8']
# link:  http://ufcstats.com/fighter-details/d562b12b8fe88336
# Extracted 124 stat:  ['JJ Ambrose', 'Record: 28-7-0 (2 NC)', '', '5\' 10"', '170 lbs.', '--', 'Orthodox', 'Feb 06, 1987', '3.16', '69%', '6.32', '33%', '0.00', '0%', '50%', '0.0']
# link:  http://ufcstats.com/fighter-details/70fa1c64a2c439ef
# Extracted 125 stat:  ['Alen Amedovski', 'Record: 8-4-0', '', '5\' 10"', '185 lbs.', '74"', 'Orthodox', 'Apr 06, 1988', '0.99', '30%', '3.85', '46%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/41cc71cbf210e0fe
# Extracted 126 stat:  ['Hyder Amil', 'Record: 11-2-0', 'The Hurricane', '5\' 9"', '145 lbs.', '70"', 'Switch', 'May 28, 1990', '5.81', '52%', '3.95', '51%', '0.56', '18%', '65%', '0.8']
# link:  http://ufcstats.com/fighter-details/6c40705cf6c0d7e2
# Extracted 127 stat:  ['Hamid Amiri', 'Record: 9-0-0', 'The Storm', '--', '145 lbs.', '--', '', 'Jun 15, 2003', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/87a1dc546b1c5caf
# Extracted 128 stat:  ['Makwan Amirkhani', 'Record: 17-9-0', 'Mr. Finland', '5\' 10"', '145 lbs.', '72"', 'Southpaw', 'Nov 08, 1988', '1.33', '44%', '2.98', '46%', '3.96', '43%', '35%', '1.1']
# link:  http://ufcstats.com/fighter-details/bc7d1ad49fcb2d08
# Extracted 129 stat:  ['Jaqueline Amorim', 'Record: 10-2-0', '', '5\' 3"', '115 lbs.', '68"', 'Orthodox', 'Jun 24, 1995', '2.43', '50%', '2.16', '54%', '2.16', '36%', '0%', '3.8']
# link:  http://ufcstats.com/fighter-details/f139d6836efd43dd
# Extracted 130 stat:  ['Yaroslav Amosov', 'Record: 29-1-0', '', '6\' 0"', '170 lbs.', '75"', 'Orthodox', 'Sep 09, 1993', '2.78', '47%', '1.55', '54%', '4.64', '50%', '0%', '4.6']
# link:  http://ufcstats.com/fighter-details/53adf5b845d91e4a
# Extracted 131 stat:  ['Bertrand Amoussou', 'Record: 1-1-0', '', '5\' 8"', '190 lbs.', '--', 'Orthodox', 'May 28, 1966', '6.75', '39%', '2.01', '83%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/23a8c33869bf5392
# Extracted 132 stat:  ['Karl Amoussou', 'Record: 27-7-2', 'The Psycho', '5\' 11"', '185 lbs.', '--', 'Orthodox', 'Nov 21, 1985', '1.47', '34%', '2.67', '54%', '0.00', '0%', '25%', '1.0']
# link:  http://ufcstats.com/fighter-details/cad24459b28592ca
# Extracted 133 stat:  ['Eryk Anders', 'Record: 17-9-0 (1 NC)', 'Ya Boi', '6\' 1"', '185 lbs.', '75"', 'Southpaw', 'Apr 21, 1987', '3.51', '48%', '4.09', '50%', '1.75', '24%', '80%', '0.1']
# link:  http://ufcstats.com/fighter-details/8738eacd62e82a32
# Extracted 134 stat:  ['Matt Andersen', 'Record: 14-8-1', '', '6\' 2"', '230 lbs.', '--', 'Southpaw', 'May 29, 1971', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/9199e0735b83dd32
# Extracted 135 stat:  ['Andy Anderson', 'Record: 0-1-0', 'The Hammer', '5\' 6"', '240 lbs.', '--', '', 'Jul 16, 1974', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/1ffc38f67785797b
# Extracted 136 stat:  ['Lowell Anderson', 'Record: 0-1-0', '', '5\' 6"', '160 lbs.', '--', 'Orthodox', '--', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/5e4eec08896c9423
# Extracted 137 stat:  ['Corey Anderson', 'Record: 14-5-0', 'Overtime', '6\' 3"', '205 lbs.', '79"', 'Orthodox', 'Sep 22, 1989', '4.43', '46%', '2.22', '59%', '4.89', '50%', '83%', '0.0']
# link:  http://ufcstats.com/fighter-details/19ba965651486013
# Extracted 138 stat:  ['Derek Anderson', 'Record: 14-3-0 (1 NC)', 'Barbaric', '6\' 0"', '155 lbs.', '--', '', 'Feb 02, 1990', '3.97', '37%', '3.08', '61%', '0.34', '14%', '60%', '0.0']
# link:  http://ufcstats.com/fighter-details/a0e75f4a13eb73f1
# Extracted 139 stat:  ['Megan Anderson', 'Record: 11-5-0', '', '6\' 0"', '145 lbs.', '72"', 'Orthodox', 'Feb 11, 1990', '1.76', '46%', '3.35', '37%', '0.52', '25%', '53%', '0.5']
# link:  http://ufcstats.com/fighter-details/b03a0c78ca45facf
# Extracted 140 stat:  ['Liam Anderson', 'Record: 6-3-0', '', '6\' 3"', '185 lbs.', '75"', 'Orthodox', 'Jan 13, 1995', '3.00', '52%', '6.53', '31%', '1.00', '20%', '50%', '0.0']
# link:  http://ufcstats.com/fighter-details/17615148dd4be6f6
# Extracted 141 stat:  ['Tatsuya Ando', 'Record: 14-4-1', 'Kirinji', '5\' 4"', '145 lbs.', '68"', 'Southpaw', 'Apr 26, 1990', '0.93', '19%', '4.93', '50%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/1562b12763cc8d67
# Extracted 142 stat:  ['Alex Andrade', 'Record: 10-5-0', 'El Toro', '5\' 11"', '200 lbs.', '--', 'Orthodox', 'May 14, 1974', '0.20', '36%', '2.60', '53%', '0.00', '0%', '25%', '0.8']
# link:  http://ufcstats.com/fighter-details/6a1901c62ab3870f
# Extracted 143 stat:  ['Jessica Andrade', 'Record: 26-15-0', 'Bate Estaca', '5\' 1"', '115 lbs.', '62"', 'Orthodox', 'Sep 25, 1991', '6.37', '48%', '5.58', '54%', '2.10', '54%', '75%', '0.3']
# link:  http://ufcstats.com/fighter-details/d221ee27afc7a60e
# Extracted 144 stat:  ['Viscardi Andrade', 'Record: 19-6-0', '', '5\' 11"', '170 lbs.', '75"', 'Orthodox', 'Mar 08, 1984', '3.26', '42%', '2.77', '63%', '1.93', '50%', '66%', '0.3']
# link:  http://ufcstats.com/fighter-details/9bad58fa651d6196
# Extracted 145 stat:  ['Jermaine Andre', 'Record: 14-4-0', '', '5\' 7"', '200 lbs.', '--', 'Orthodox', 'Jul 16, 1973', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/7977fb0fd9c5955d
# Extracted 146 stat:  ['Fellipe Andrew', 'Record: 0-0-0', '', '--', '--', '--', '', 'Oct 24, 1994', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/00debc804e2b1cd4
# Extracted 147 stat:  ['Dylan Andrews', 'Record: 18-7-0 (1 NC)', 'The Villain', '6\' 1"', '185 lbs.', '74"', 'Switch', 'Nov 15, 1979', '2.21', '50%', '2.72', '46%', '2.83', '50%', '57%', '0.4']
# link:  http://ufcstats.com/fighter-details/46e2ca71fd5089cb
# Extracted 148 stat:  ['Reese Andy', 'Record: 7-3-0', 'Riptide', '6\' 0"', '205 lbs.', '--', 'Orthodox', 'Mar 31, 1973', '2.87', '50%', '3.50', '58%', '0.67', '20%', '40%', '0.0']
# link:  http://ufcstats.com/fighter-details/d6a3e131ad4ba064
# Extracted 149 stat:  ['Angga', 'Record: 13-3-0', 'The Hitman', '5\' 7"', '145 lbs.', '68"', 'Orthodox', 'Jan 13, 1989', '3.56', '38%', '3.77', '53%', '0.00', '0%', '33%', '0.0']
# link:  http://ufcstats.com/fighter-details/e20ad078a7d63361
# Extracted 150 stat:  ['Julius Anglickas', 'Record: 5-1-0', '', '6\' 3"', '205 lbs.', '--', 'Orthodox', 'Jul 23, 1991', '4.62', '78%', '1.86', '50%', '4.47', '50%', '60%', '1.1']
# link:  http://ufcstats.com/fighter-details/047a91d3d9c79b05
# Extracted 151 stat:  ['Collin Anglin', 'Record: 8-3-0', '', '5\' 9"', '145 lbs.', '71"', 'Orthodox', 'Feb 20, 1993', '4.59', '48%', '5.54', '51%', '2.28', '66%', '100%', '0.0']
# link:  http://ufcstats.com/fighter-details/c7c39e2fb70248b3
# Extracted 152 stat:  ['Chad Anheliger', 'Record: 13-8-0', 'The Monster', '5\' 6"', '135 lbs.', '64"', 'Orthodox', 'Dec 01, 1986', '3.11', '46%', '2.76', '53%', '0.68', '30%', '38%', '0.5']
# link:  http://ufcstats.com/fighter-details/e06fd1260ac865a7
# Extracted 153 stat:  ['Yoji Anjo', 'Record: 0-5-1', 'Mr. 200%', '5\' 11"', '205 lbs.', '--', 'Orthodox', 'Mar 28, 1967', '0.00', '0%', '3.13', '25%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/d802174b0c0c1f4e
# Extracted 154 stat:  ['Magomed Ankalaev', 'Record: 21-2-1 (1 NC)', '', '6\' 3"', '205 lbs.', '75"', 'Orthodox', 'Jun 02, 1992', '3.65', '52%', '2.59', '56%', '0.79', '22%', '87%', '0.0']
# link:  http://ufcstats.com/fighter-details/af997f7611673880
# Extracted 155 stat:  ['Gadzhimurad Antigulov', 'Record: 20-8-0', '', '5\' 11"', '205 lbs.', '70"', 'Orthodox', 'Feb 09, 1987', '2.08', '55%', '4.21', '40%', '5.08', '36%', '0%', '1.4']
# link:  http://ufcstats.com/fighter-details/25b31165758402dd
# Extracted 156 stat:  ['Adam Antolin', 'Record: 12-3-0', 'Captain Chaos', '5\' 5"', '125 lbs.', '63"', 'Orthodox', 'Feb 28, 1982', '5.73', '52%', '5.00', '69%', '0.00', '0%', '100%', '0.0']
# link:  http://ufcstats.com/fighter-details/dbd198f780286aca
# Extracted 157 stat:  ['Angelo Antonio', 'Record: 1-4-0', '', '--', '205 lbs.', '--', 'Orthodox', 'Oct 04, 1998', '1.09', '50%', '7.64', '50%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/cc49ada1ea955b13
# Extracted 158 stat:  ['Vanilto Antunes', 'Record: 16-7-0', '', '6\' 0"', '170 lbs.', '72"', 'Orthodox', 'Dec 28, 1994', '5.49', '48%', '14.27', '43%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/78d48d3874dacafd
# Extracted 159 stat:  ['Azunna Anyanwu', 'Record: 14-5-0', 'Zulu', '6\' 1"', '251 lbs.', '--', 'Orthodox', 'Aug 05, 1981', '2.47', '42%', '2.47', '69%', '0.65', '100%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/4665f9f909cd7214
# Extracted 160 stat:  ['Shinsho Anzai', 'Record: 10-3-0', 'Animal', '5\' 7"', '170 lbs.', '70"', 'Orthodox', 'Dec 01, 1985', '3.23', '58%', '3.75', '45%', '1.83', '16%', '75%', '0.0']
# link:  http://ufcstats.com/fighter-details/031da10a00c8ccd4
# Extracted 161 stat:  ['Jin Aoi', 'Record: 14-6-1', '', '5\' 6"', '145 lbs.', '68"', 'Orthodox', 'Jan 21, 1997', '1.60', '29%', '5.80', '51%', '0.00', '0%', '71%', '0.0']
# link:  http://ufcstats.com/fighter-details/79ded75550efc139
# Extracted 162 stat:  ['Shinya Aoki', 'Record: 39-7-0 (1 NC)', 'Tobikan Judan', '5\' 11"', '154 lbs.', '--', 'Southpaw', 'May 09, 1983', '0.97', '58%', '1.25', '58%', '2.54', '41%', '60%', '4.0']
# link:  http://ufcstats.com/fighter-details/7d420039bbfe7c1a
# Extracted 163 stat:  ['Aoriqileng', 'Record: 26-12-0 (1 NC)', 'The Mongolian Murderer', '5\' 7"', '135 lbs.', '69"', 'Orthodox', 'Jun 25, 1993', '4.69', '49%', '5.47', '48%', '1.20', '46%', '58%', '0.0']
# link:  http://ufcstats.com/fighter-details/0c1a04afca64e38f
# Extracted 164 stat:  ['Josh Appelt', 'Record: 15-7-0', '', '5\' 10"', '255 lbs.', '--', 'Southpaw', 'Jun 19, 1983', '1.35', '40%', '11.50', '32%', '0.00', '0%', '33%', '0.0']
# link:  http://ufcstats.com/fighter-details/1ccff7f0cfdf85eb
# Extracted 165 stat:  ['Erik Apple', 'Record: 10-3-0', '', '6\' 0"', '170 lbs.', '--', 'Orthodox', 'Aug 26, 1977', '0.00', '0%', '0.54', '81%', '0.00', '0%', '0%', '8.1']
# link:  http://ufcstats.com/fighter-details/269d103c96a4c3a5
# Extracted 166 stat:  ['Kenji Arai', 'Record: 15-15-5', '', '5\' 10"', '145 lbs.', '--', 'Southpaw', 'Oct 05, 1979', '8.79', '27%', '10.29', '39%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/73ef22f25d0f70e2
# Extracted 167 stat:  ['Romie Aram', 'Record: 7-1-0', '', '5\' 10"', '170 lbs.', '--', 'Orthodox', 'Dec 02, 1977', '1.80', '35%', '2.83', '50%', '2.50', '62%', '83%', '0.0']
# link:  http://ufcstats.com/fighter-details/71002dbc1743b9a7
# Extracted 168 stat:  ['Felipe Arantes', 'Record: 18-10-1 (2 NC)', 'Sertanejo', '5\' 8"', '135 lbs.', '73"', 'Orthodox', 'Feb 09, 1988', '2.37', '45%', '2.66', '64%', '0.93', '47%', '41%', '0.7']
# link:  http://ufcstats.com/fighter-details/dbea8c1cb327ab3d
# Extracted 169 stat:  ['Igor Araujo', 'Record: 25-9-0 (1 NC)', '', '6\' 1"', '170 lbs.', '77"', 'Orthodox', 'Dec 06, 1980', '1.52', '42%', '2.86', '49%', '0.86', '15%', '22%', '0.6']
# link:  http://ufcstats.com/fighter-details/36541f1e6c5d4955
# Extracted 170 stat:  ['Viviane Araujo', 'Record: 13-7-0', 'Vivi', '5\' 4"', '125 lbs.', '68"', 'Orthodox', 'Nov 21, 1986', '3.84', '47%', '4.83', '55%', '1.72', '43%', '75%', '0.6']
# link:  http://ufcstats.com/fighter-details/1291edf2d566a71a
# Extracted 171 stat:  ['Julio Arce', 'Record: 19-6-0', '', '5\' 7"', '145 lbs.', '70"', 'Southpaw', 'Oct 27, 1989', '4.36', '36%', '3.05', '68%', '0.46', '28%', '96%', '0.3']
# link:  http://ufcstats.com/fighter-details/d25e39e74efb0a77
# Extracted 172 stat:  ['Art Arciniega', 'Record: 15-7-0', 'King Arthur', '5\' 8"', '145 lbs.', '--', '', 'Oct 15, 1981', '1.53', '46%', '2.73', '51%', '0.00', '0%', '50%', '1.0']
# link:  http://ufcstats.com/fighter-details/87f8699fdcc2c404
# Extracted 173 stat:  ['Alice Ardelean', 'Record: 11-7-0', '', '5\' 3"', '115 lbs.', '62"', 'Orthodox', 'Apr 19, 1992', '7.35', '45%', '5.20', '62%', '1.00', '44%', '85%', '0.0']
# link:  http://ufcstats.com/fighter-details/9c9455912d917e4e
# Extracted 174 stat:  ['Tristan Arenal', 'Record: 7-4-0', '', '--', '155 lbs.', '--', '', 'Mar 06, 1985', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/db3c4a884d704efe
# Extracted 175 stat:  ['Gabriel Arges', 'Record: 0-0-0', '', '--', '170 lbs.', '--', '', 'Jan 29, 1993', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/e4ba58725825412d
# Extracted 176 stat:  ['Dan Argueta', 'Record: 9-3-0 (2 NC)', 'The Determined', '5\' 7"', '135 lbs.', '68"', 'Southpaw', 'Aug 13, 1993', '2.48', '43%', '3.44', '50%', '4.36', '35%', '55%', '1.4']
# link:  http://ufcstats.com/fighter-details/90063913321e7670
# Extracted 177 stat:  ['Reza Arianto', 'Record: 5-0-0', 'The Crazy Lion', '--', '155 lbs.', '--', '', '--', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/9a7ffa80766caa51
# Extracted 178 stat:  ['Hashem Arkhagha', 'Record: 6-1-0', '', '6\' 2"', '185 lbs.', '75"', 'Orthodox', 'Sep 11, 1989', '1.84', '44%', '8.97', '43%', '0.00', '0%', '50%', '0.0']
# link:  http://ufcstats.com/fighter-details/3738e68d2261e60f
# Extracted 179 stat:  ['Andrei Arlovski', 'Record: 34-24-0 (2 NC)', 'The Pitbull', '6\' 3"', '240 lbs.', '77"', 'Orthodox', 'Feb 04, 1979', '3.82', '45%', '3.22', '57%', '0.37', '35%', '76%', '0.2']
# link:  http://ufcstats.com/fighter-details/1effd880e1f1bb30
# Extracted 180 stat:  ['Garrett Armfield', 'Record: 10-5-0', '', '5\' 6"', '135 lbs.', '70"', 'Orthodox', 'Oct 09, 1996', '5.35', '53%', '3.64', '56%', '1.10', '50%', '64%', '0.6']
# link:  http://ufcstats.com/fighter-details/30ad2050273d016a
# Extracted 181 stat:  ['Joey Armstrong', 'Record: 5-2-0', '', '--', '--', '--', '', '--', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/bf0e700106d00e55
# Extracted 182 stat:  ['Austin Arnett', 'Record: 16-6-0', '', '6\' 0"', '145 lbs.', '72"', 'Orthodox', 'Oct 22, 1991', '4.52', '41%', '6.38', '62%', '0.44', '18%', '57%', '0.2']
# link:  http://ufcstats.com/fighter-details/05fbfe628658c538
# Extracted 183 stat:  ['Ricardo Arona', 'Record: 14-5-0', 'The Brazilian Tiger', '5\' 11"', '205 lbs.', '--', 'Orthodox', 'Jul 17, 1978', '1.66', '48%', '1.15', '57%', '2.41', '48%', '58%', '1.2']
# link:  http://ufcstats.com/fighter-details/a90c200c3fbb22c4
# Extracted 184 stat:  ['Eli Aronov', 'Record: 6-1-0', 'The Israeli Tank', '5\' 10"', '185 lbs.', '72"', 'Orthodox', 'Jun 06, 1996', '8.92', '68%', '6.49', '38%', '12.16', '100%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/770b9d4813c25902
# Extracted 185 stat:  ['Chalid Arrab', 'Record: 7-3-0', 'Die Faust', '5\' 11"', '205 lbs.', '--', 'Orthodox', 'May 28, 1975', '1.56', '34%', '1.63', '56%', '3.05', '75%', '37%', '1.0']
# link:  http://ufcstats.com/fighter-details/c136b2a8852da5bd
# Extracted 186 stat:  ['Akbarh Arreola', 'Record: 23-11-1', 'El Caballero', '5\' 10"', '155 lbs.', '71"', 'Southpaw', 'Jan 14, 1983', '2.32', '45%', '4.01', '56%', '1.07', '100%', '33%', '0.4']
# link:  http://ufcstats.com/fighter-details/de62052b2ede65ba
# Extracted 187 stat:  ['Matt Arroyo', 'Record: 3-3-0', 'No Regard', '5\' 10"', '170 lbs.', '72"', 'Orthodox', 'Sep 01, 1982', '1.62', '47%', '2.01', '58%', '2.12', '36%', '100%', '5.3']
# link:  http://ufcstats.com/fighter-details/61fb8098ccf81c7f
# Extracted 188 stat:  ['Antonio Arroyo', 'Record: 9-5-0', '', '6\' 3"', '185 lbs.', '73"', 'Orthodox', 'Jul 01, 1989', '2.82', '66%', '2.02', '50%', '1.14', '41%', '41%', '0.2']
# link:  http://ufcstats.com/fighter-details/2dea80c069847321
# Extracted 189 stat:  ['Gilles Arsene', 'Record: 1-1-0', '', '5\' 9"', '190 lbs.', '--', 'Southpaw', 'Dec 23, 1970', '0.06', '10%', '2.45', '32%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/91e3388e69060e69
# Extracted 190 stat:  ['Veta Arteaga', 'Record: 3-1-0', '', '5\' 7"', '125 lbs.', '--', '', '--', '3.20', '36%', '1.92', '65%', '0.00', '0%', '40%', '0.0']
# link:  http://ufcstats.com/fighter-details/49f78022126bf4a4
# Extracted 191 stat:  ['Cesar Arzamendia', 'Record: 8-3-0', 'Goku', '5\' 11"', '155 lbs.', '--', 'Orthodox', 'Jan 31, 1991', '5.37', '45%', '5.20', '56%', '7.32', '75%', '0%', '2.4']
# link:  http://ufcstats.com/fighter-details/d33da8a3d82bdb62
# Extracted 192 stat:  ['Kai Asakura', 'Record: 21-6-0', '', '5\' 8"', '125 lbs.', '69"', 'Orthodox', 'Oct 31, 1993', '2.27', '32%', '3.53', '52%', '0.00', '0%', '50%', '0.0']
# link:  http://ufcstats.com/fighter-details/a373085066dbfb54
# Extracted 193 stat:  ['Teddy Ash', 'Record: 14-5-0', 'Bear', '6\' 1"', '185 lbs.', '73"', 'Switch', 'Dec 27, 1989', '7.27', '61%', '6.80', '28%', '0.00', '0%', '100%', '0.0']
# link:  http://ufcstats.com/fighter-details/d26a0988c9dc9886
# Extracted 194 stat:  ['Arman Ashimov', 'Record: 11-3-1', 'Mustafa Ozturik', '5\' 6"', '125 lbs.', '--', '', 'Jan 14, 1992', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/c739c2995a275314
# Extracted 195 stat:  ['Yanal Ashmouz', 'Record: 8-2-0', 'Red Fox', '5\' 9"', '155 lbs.', '69"', 'Orthodox', 'Mar 31, 1995', '2.88', '50%', '4.78', '50%', '3.24', '38%', '64%', '0.0']
# link:  http://ufcstats.com/fighter-details/8be9deb7d6b36354
# Extracted 196 stat:  ['Asjabharan', 'Record: 7-6-0', '', '5\' 6"', '135 lbs.', '--', '', 'Jul 31, 1992', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/2abc414136504554
# Extracted 197 stat:  ['Askar Askar', 'Record: 11-1-0', 'AK-47', '5\' 7"', '145 lbs.', '69"', 'Orthodox', 'Aug 19, 1994', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/b1d19449397541dc
# Extracted 198 stat:  ['Askar Askarov', 'Record: 14-1-1', 'Bullet', '5\' 6"', '125 lbs.', '67"', 'Orthodox', 'Oct 09, 1992', '3.05', '54%', '2.80', '57%', '2.60', '24%', '66%', '0.4']
# link:  http://ufcstats.com/fighter-details/9be6020024133293
# Extracted 199 stat:  ['Cyril Asker', 'Record: 9-4-0', 'Silverback', '6\' 0"', '247 lbs.', '74"', 'Orthodox', 'Dec 24, 1985', '3.35', '39%', '5.82', '35%', '4.41', '62%', '100%', '0.9']
# link:  http://ufcstats.com/fighter-details/5c10da56d712ac9c
# Extracted 200 stat:  ['Khusein Askhabov', 'Record: 23-1-0', 'Nohcho', '5\' 8"', '145 lbs.', '69"', 'Orthodox', 'Feb 13, 1995', '2.00', '26%', '4.13', '56%', '0.00', '0%', '66%', '0.0']
# ...
# link:  http://ufcstats.com/fighter-details/24656ef4d605c96f
# Extracted 4412 stat:  ['Aiemann Zahabi', 'Record: 14-2-0', '', '5\' 8"', '135 lbs.', '68"', 'Orthodox', 'Nov 19, 1987', '4.54', '47%', '4.08', '69%', '0.12', '14%', '83%', '0.0']
# link:  http://ufcstats.com/fighter-details/6b614bda982f5214
# Extracted 4413 stat:  ['Joao Zaiden', 'Record: 10-3-0', '', '--', '205 lbs.', '--', '', 'Mar 16, 1993', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/52c2ae6d2f2d2613
# Extracted 4414 stat:  ['Youssef Zalal', 'Record: 18-5-1', 'The Moroccan Devil', '5\' 10"', '145 lbs.', '72"', 'Switch', 'Sep 04, 1996', '3.03', '50%', '1.78', '66%', '2.17', '31%', '59%', '1.4']
# link:  http://ufcstats.com/fighter-details/8adcbd525fab8d9b
# Extracted 4415 stat:  ['Elizeu Zaleski dos Santos', 'Record: 25-10-1', 'Capoeira', '5\' 11"', '170 lbs.', '73"', 'Orthodox', 'Dec 11, 1986', '4.16', '41%', '3.56', '55%', '0.79', '20%', '67%', '0.4']
# link:  http://ufcstats.com/fighter-details/cc3878d1ab41a5fa
# Extracted 4416 stat:  ['Zach Zane', 'Record: 10-7-0', 'The Hurricane', '5\' 7"', '145 lbs.', '69"', 'Southpaw', 'Dec 14, 1989', '0.87', '56%', '6.67', '20%', '0.00', '0%', '26%', '0.0']
# link:  http://ufcstats.com/fighter-details/fe5ca7ef93c3f6a7
# Extracted 4417 stat:  ['Roger Zapata', 'Record: 4-2-0', 'Viva', '5\' 11"', '170 lbs.', '--', 'Southpaw', 'May 09, 1986', '2.60', '51%', '2.13', '36%', '0.00', '0%', '81%', '1.4']
# link:  http://ufcstats.com/fighter-details/abcf7e55a0a9ed89
# Extracted 4418 stat:  ['Marius Zaromskis', 'Record: 20-9-0 (1 NC)', 'The Whitemare', '5\' 9"', '170 lbs.', '--', 'Orthodox', 'Jul 30, 1980', '5.02', '34%', '5.93', '50%', '0.73', '42%', '73%', '0.0']
# link:  http://ufcstats.com/fighter-details/3bb2dc8e87b10a46
# Extracted 4419 stat:  ['David Zawada', 'Record: 17-7-0', 'Sagat', '6\' 0"', '170 lbs.', '75"', 'Orthodox', 'Aug 01, 1990', '3.84', '41%', '4.54', '55%', '0.97', '33%', '57%', '1.7']
# link:  http://ufcstats.com/fighter-details/04ff3a711504d6b3
# Extracted 4420 stat:  ['Magomed Zaynukov', 'Record: 8-0-0', 'Wild Chanco', '5\' 10"', '155 lbs.', '68"', 'Orthodox', 'Jan 02, 1995', '15.67', '60%', '4.80', '58%', '2.00', '100%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/fd7ab338e4953644
# Extracted 4421 stat:  ['Manolo Zecchini', 'Record: 11-4-0', 'Angelo Veneziano', '5\' 8"', '145 lbs.', '68"', 'Orthodox', 'Oct 22, 1996', '2.34', '21%', '6.75', '46%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/be4076c9e8d791e3
# Extracted 4422 stat:  ['Joao Zeferino', 'Record: 21-9-0', 'The Brazilian Samurai', '5\' 11"', '170 lbs.', '--', 'Orthodox', 'Jan 15, 1986', '0.83', '36%', '2.60', '48%', '0.50', '5%', '50%', '1.0']
# link:  http://ufcstats.com/fighter-details/4148802ae4a50768
# Extracted 4423 stat:  ['Daniel Zellhuber', 'Record: 15-3-0', 'Golden Boy', '6\' 1"', '155 lbs.', '77"', 'Switch', 'Jul 07, 1999', '5.83', '39%', '5.91', '56%', '0.15', '25%', '94%', '0.1']
# link:  http://ufcstats.com/fighter-details/3794e5e0bb0defb6
# Extracted 4424 stat:  ['Craig Zellner', 'Record: 4-3-0', 'Big Z', '6\' 2"', '205 lbs.', '--', 'Orthodox', 'Sep 09, 1976', '0.61', '9%', '4.65', '61%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/c879d8620261b1a3
# Extracted 4425 stat:  ['Rickson Zenidim', 'Record: 14-2-0', 'The King', '5\' 7"', '125 lbs.', '67"', 'Orthodox', 'Feb 17, 1999', '1.67', '32%', '4.07', '33%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/3144121470023e9a
# Extracted 4426 stat:  ['Roman Zentsov', 'Record: 18-12-0', 'The Russian Hammer', '6\' 1"', '230 lbs.', '--', 'Orthodox', 'Sep 10, 1973', '1.18', '36%', '0.53', '70%', '1.60', '100%', '33%', '3.2']
# link:  http://ufcstats.com/fighter-details/cbf69fa846c7e3ee
# Extracted 4427 stat:  ['Carlos Zevallos', 'Record: 3-4-0', '', '6\' 0"', '205 lbs.', '--', 'Orthodox', 'Sep 05, 1978', '4.36', '65%', '2.28', '68%', '0.00', '0%', '100%', '0.0']
# link:  http://ufcstats.com/fighter-details/c23e3d4875340d8d
# Extracted 4428 stat:  ['Zhang Tiequan', 'Record: 15-4-0', 'The Wolf', '5\' 8"', '155 lbs.', '69"', 'Orthodox', 'Jul 25, 1978', '1.23', '36%', '2.14', '51%', '1.95', '58%', '75%', '3.4']
# link:  http://ufcstats.com/fighter-details/7b310409440c9102
# Extracted 4429 stat:  ['Zhang Lipeng', 'Record: 23-9-1', 'The Warrior', '5\' 11"', '155 lbs.', '71"', 'Southpaw', 'Mar 10, 1990', '1.28', '48%', '1.88', '53%', '1.75', '30%', '69%', '0.8']
# link:  http://ufcstats.com/fighter-details/1ebe20ebbfa15e29
# Extracted 4430 stat:  ['Zhang Weili', 'Record: 26-4-0', 'Magnum', '5\' 4"', '115 lbs.', '63"', 'Switch', 'Aug 13, 1989', '4.66', '52%', '2.63', '53%', '1.96', '44%', '63%', '0.5']
# link:  http://ufcstats.com/fighter-details/8a65fd9ba31fd3f7
# Extracted 4431 stat:  ['Zhang Mingyang', 'Record: 19-7-0', 'Mountain Tiger', '6\' 2"', '205 lbs.', '75"', 'Orthodox', 'Aug 16, 1998', '7.71', '60%', '5.33', '43%', '0.00', '0%', '75%', '0.0']
# link:  http://ufcstats.com/fighter-details/45c7979c71751fcf
# Extracted 4432 stat:  ['Zhang Qinghe', 'Record: 16-8-1', '', '5\' 7"', '135 lbs.', '67"', 'Southpaw', 'Nov 05, 2001', '2.87', '33%', '4.73', '49%', '0.00', '0%', '50%', '0.0']
# link:  http://ufcstats.com/fighter-details/286e1d61fb315355
# Extracted 4433 stat:  ['Zhang Zhenyang', 'Record: 7-2-0', '', '--', '155 lbs.', '--', '', '--', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/fd52e5f9ab25c94c
# Extracted 4434 stat:  ['Daermisi Zhawupasi', 'Record: 9-2-0', '', '5\' 8"', '135 lbs.', '68"', 'Switch', 'Sep 15, 1999', '1.86', '40%', '2.36', '55%', '7.74', '65%', '53%', '1.4']
# link:  http://ufcstats.com/fighter-details/07047eb7d17fb0a2
# Extracted 4435 stat:  ['Daria Zhelezniakova', 'Record: 10-2-0', 'Iron Lady', '5\' 9"', '135 lbs.', '68"', 'Orthodox', 'Jan 23, 1996', '4.75', '41%', '2.83', '68%', '0.44', '100%', '50%', '0.0']
# link:  http://ufcstats.com/fighter-details/5ea918ea81b7dee2
# Extracted 4436 stat:  ['Yao Zhikui', 'Record: 2-4-0', 'The Conqueror', '5\' 5"', '125 lbs.', '64"', 'Orthodox', 'Feb 07, 1991', '1.44', '21%', '2.82', '48%', '0.66', '16%', '58%', '0.0']
# link:  http://ufcstats.com/fighter-details/d027fff39a34a9df
# Extracted 4437 stat:  ['Zhou Kun', 'Record: 13-4-0', 'Mandrill', '--', '125 lbs.', '--', '', '--', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/6f4ec5aa3eced219
# Extracted 4438 stat:  ['Zhu Kangjie', 'Record: 21-4-0 (1 NC)', '', '5\' 8"', '145 lbs.', '70"', 'Orthodox', 'Jan 16, 1996', '2.89', '48%', '1.33', '70%', '0.33', '100%', '51%', '0.0']
# link:  http://ufcstats.com/fighter-details/55fa6ce3e522c8bb
# Extracted 4439 stat:  ['Zhalgas Zhumagulov', 'Record: 14-9-0', '', '5\' 4"', '125 lbs.', '66"', 'Switch', 'Aug 29, 1988', '5.24', '43%', '5.86', '52%', '1.30', '19%', '75%', '0.2']
# link:  http://ufcstats.com/fighter-details/1e4f273069fb9e85
# Extracted 4440 stat:  ['Fares Ziam', 'Record: 18-4-0', 'The Smile Killer', '6\' 1"', '155 lbs.', '75"', 'Orthodox', 'Mar 21, 1997', '2.87', '52%', '1.53', '65%', '1.73', '40%', '71%', '0.5']
# link:  http://ufcstats.com/fighter-details/6d3398b910461f2f
# Extracted 4441 stat:  ['Mike Zichelle', 'Record: 8-4-0', '', '--', '205 lbs.', '--', '', '--', '0.87', '35%', '0.87', '40%', '0.00', '0%', '0%', '2.0']
# link:  http://ufcstats.com/fighter-details/4b4fc3ddc307bc73
# Extracted 4442 stat:  ['James Zikic', 'Record: 21-10-2', 'The Messenger', '6\' 2"', '205 lbs.', '--', 'Orthodox', 'Mar 01, 1977', '1.47', '35%', '1.60', '44%', '0.50', '25%', '74%', '0.5']
# link:  http://ufcstats.com/fighter-details/0aa74d04c196800c
# Extracted 4443 stat:  ['Errol Zimmerman', 'Record: 0-1-0', 'The Bonecrusher', '6\' 3"', '185 lbs.', '--', 'Orthodox', 'Apr 20, 1986', '2.95', '42%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/3ecd936bd8814108
# Extracted 4444 stat:  ['Cat Zingano', 'Record: 10-4-0', 'Alpha', '5\' 6"', '145 lbs.', '68"', 'Southpaw', 'Jul 01, 1982', '2.57', '61%', '1.63', '47%', '2.77', '65%', '42%', '0.8']
# link:  http://ufcstats.com/fighter-details/108afe61a26bcbf4
# Extracted 4445 stat:  ['Igor Zinoviev', 'Record: 4-1-2', 'Houdini', '6\' 1"', '199 lbs.', '--', 'Orthodox', 'May 23, 1966', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/be124bdd60fab7d5
# Extracted 4446 stat:  ['Dave Zitanick', 'Record: 5-7-0 (1 NC)', '', '--', '170 lbs.', '--', '', 'Mar 05, 1980', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/02d808afb96669de
# Extracted 4447 stat:  ['Alex Zuniga', 'Record: 6-3-0', '', '--', '145 lbs.', '--', '', '--', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/1291dd6b8ab4d952
# Extracted 4448 stat:  ['George Zuniga', 'Record: 3-1-0', '', '5\' 9"', '185 lbs.', '--', '', '--', '7.64', '38%', '5.45', '37%', '0.00', '0%', '100%', '0.0']
# link:  http://ufcstats.com/fighter-details/523af801b3429015
# Extracted 4449 stat:  ['Allan Zuniga', 'Record: 13-1-0', 'Tigre', '5\' 7"', '155 lbs.', '70"', 'Orthodox', 'Apr 04, 1992', '3.93', '52%', '1.80', '61%', '0.00', '0%', '57%', '1.0']
# link:  http://ufcstats.com/fighter-details/392878af4680849f
# Extracted 4450 stat:  ['Brahyam Zurcher', 'Record: 9-1-0', 'El Jarretas', '5\' 10"', '145 lbs.', '70"', 'Orthodox', 'Mar 10, 1996', '1.86', '15%', '5.57', '59%', '0.00', '0%', '0%', '0.0']
# link:  http://ufcstats.com/fighter-details/0c277f3ff66b0208
# Extracted 4451 stat:  ['Virgil Zwicker', 'Record: 15-6-1', 'RezDog', '6\' 2"', '205 lbs.', '74"', '', 'Jun 26, 1982', '3.34', '48%', '4.87', '39%', '1.31', '30%', '50%', '0.0']
# [['Tom Aaron', 'Record: 5-3-0', '', '--', '155 lbs.', '--', '', 'Jul 13, 1978', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0'], ['Danny Abbadi', 'Record: 4-6-0', 'The Assassin', '5\' 11"', '155 lbs.', '--', 'Orthodox', 'Jul 03, 1983', '3.29', '38%', '4.41', '57%', '0.00', '0%', '77%', '0.0'], ['Nariman Abbasov', 'Record: 28-4-0', 'Bayraktar', '5\' 8"', '155 lbs.', '66"', 'Orthodox', 'Feb 01, 1994', '3.00', '20%', '5.67', '46%', '0.00', '0%', '66%', '0.0'], ['Darion Abbey', 'Record: 9-5-0', '', '6\' 2"', '265 lbs.', '80"', 'Orthodox', 'Feb 25, 1993', '8.44', '50%', '14.06', '28%', '0.00', '0%', '0%', '0.0'], ['David Abbott', 'Record: 10-15-0', 'Tank', '6\' 0"', '265 lbs.', '--', 'Switch', 'Apr 26, 1965', '1.35', '30%', '3.55', '38%', '1.07', '33%', '66%', '0.0'], ['Hamdy Abdelwahab', 'Record: 7-1-0 (1 NC)', 'The Hammer', '6\' 2"', '265 lbs.', '72"', 'Southpaw', 'Jan 22, 1993', '4.27', '55%', '3.67', '51%', '3.25', '65%', '100%', '0.0'], ['Mansur Abdul-Malik', 'Record: 9-0-1', '', '6\' 2"', '185 lbs.', '80"', 'Orthodox', 'Oct 07, 1997', '4.18', '48%', '3.46', '51%', '0.94', '50%', '83%', '0.5'], ['Shamil Abdurakhimov', 'Record: 20-8-0', 'Abrek', '6\' 3"', '235 lbs.', '76"', 'Orthodox', 'Sep 02, 1981', '2.41', '44%', '3.02', '55%', '1.01', '23%', '45%', '0.1'], ['Hiroyuki Abe', 'Record: 8-15-3 (1 NC)', 'Abe Ani', '5\' 6"', '145 lbs.', '--', 'Orthodox', 'Feb 09, 1970', '1.71', '36%', '3.11', '63%', '0.00', '0%', '33%', '0.0'], ['Daichi Abe', 'Record: 6-2-0', '', '5\' 11"', '170 lbs.', '71"', 'Orthodox', 'Nov 27, 1991', '3.80', '33%', '4.49', '56%', '0.33', '50%', '0%', '0.0'], ['Papy Abedi', 'Record: 10-4-0', 'Makambo', '5\' 11"', '185 lbs.', '--', 'Southpaw', 'Jun 30, 1978', '2.80', '55%', '3.15', '48%', '3.47', '57%', '50%', '1.3'], ['Ricardo Abreu', 'Record: 5-1-0', 'Demente', '5\' 11"', '185 lbs.', '--', 'Orthodox', 'Apr 27, 1984', '3.79', '31%', '3.98', '68%', '2.13', '42%', '100%', '0.7'], ['Klidson Abreu', 'Record: 15-4-0 (1 NC)', 'White Bear', '6\' 0"', '205 lbs.', '74"', 'Orthodox', 'Dec 24, 1992', '2.05', '40%', '2.90', '55%', '0.64', '20%', '80%', '0.0'], ['Cyborg Abreu', 'Record: 0-0-0', '', '--', '--', '--', '', 'Dec 20, 1980', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0'], ['Daniel Acacio', 'Record: 30-18-0', '', '5\' 8"', '180 lbs.', '--', 'Orthodox', 'Dec 27, 1977', '3.52', '36%', '2.85', '62%', '0.33', '20%', '81%', '0.0'], ['John Adajar', 'Record: 6-2-0', 'The Outlaw', '5\' 9"', '170 lbs.', '75"', 'Orthodox', 'Jun 22, 1991', '3.90', '52%', '6.28', '44%', '0.00', '0%', '0%', '0.0'], ['Scott Adams', 'Record: 8-1-0', '', '6\' 0"', '225 lbs.', '--', 'Southpaw', '--', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0'], ['Juan Adams', 'Record: 5-3-0', 'The Kraken', '6\' 5"', '265 lbs.', '80"', 'Orthodox', 'Jan 16, 1992', '7.09', '55%', '4.06', '34%', '0.91', '66%', '57%', '0.0'], ['Anthony Adams', 'Record: 8-2-0', 'Sugafoot', '6\' 1"', '185 lbs.', '76"', 'Orthodox', 'Jan 13, 1988', '3.17', '41%', '5.93', '44%', '0.00', '0%', '0%', '0.0'], ['Zarrukh Adashev', 'Record: 4-4-0', 'The Lion', '5\' 5"', '125 lbs.', '65"', 'Southpaw', 'Jul 29, 1992', '3.65', '40%', '3.04', '64%', '0.00', '0%', '100%', '0.5'], ['Israel Adesanya', 'Record: 24-5-0', 'The Last Stylebender', '6\' 4"', '185 lbs.', '80"', 'Switch', 'Jul 22, 1989', '4.02', '48%', '3.20', '55%', '0.05', '11%', '76%', '0.1'], ['Sam Adkins', 'Record: 7-20-2', 'The Experience', '6\' 3"', '225 lbs.', '--', 'Orthodox', 'Apr 26, 1965', '0.00', '0%', '0.00', '0%', '0.00', '0%', '0%', '0.0'], ['Mohamed Ado', 'Record: 5-1-0', '', '5\' 11"', '170 lbs.', '76"', 'Switch', 'May 03, 2000', '1.66', '83%', '0.33', '75%', '4.97', '50%', '50%', '5.0'], ['Nick Agallar', 'Record: 24-6-0', '', '5\' 8"', '155 lbs.', '--', 'Orthodox', 'Jan 13, 1979', '0.69', '11%', '4.56', '42%', '0.00', '0%', '0%', '0.0'], ['Mariya Agapova', 'Record: 10-5-0', 'Money Mashka', '5\' 6"', '125 lbs.', '68"', 'Southpaw', 'Apr 07, 1997', '4.43', '54%', '3.62', '52%', '0.55', '66%', '45%', '0.8 ...
#                  NAME           RECORD      NICKNAME  HEIGHT    WEIGHT REACH  \
# 0           Tom Aaron    Record: 5-3-0                    --  155 lbs.    --
# 1        Danny Abbadi    Record: 4-6-0  The Assassin  5' 11"  155 lbs.    --
# 2     Nariman Abbasov   Record: 28-4-0     Bayraktar   5' 8"  155 lbs.   66"
# 3        Darion Abbey    Record: 9-5-0                 6' 2"  265 lbs.   80"
# 4        David Abbott  Record: 10-15-0          Tank   6' 0"  265 lbs.    --
# ...               ...              ...           ...     ...       ...   ...
# 4447      Alex Zuniga    Record: 6-3-0                    --  145 lbs.    --
# 4448    George Zuniga    Record: 3-1-0                 5' 9"  185 lbs.    --
# 4449     Allan Zuniga   Record: 13-1-0         Tigre   5' 7"  155 lbs.   70"
# 4450  Brahyam Zurcher    Record: 9-1-0   El Jarretas  5' 10"  145 lbs.   70"
# 4451   Virgil Zwicker   Record: 15-6-1        RezDog   6' 2"  205 lbs.   74"
#
#         STANCE           DOB  SLpM Str. Acc.   SApM Str. Def. TD Avg. TD Acc.  \
# 0               Jul 13, 1978  0.00        0%   0.00        0%    0.00      0%
# 1     Orthodox  Jul 03, 1983  3.29       38%   4.41       57%    0.00      0%
# 2     Orthodox  Feb 01, 1994  3.00       20%   5.67       46%    0.00      0%
# 3     Orthodox  Feb 25, 1993  8.44       50%  14.06       28%    0.00      0%
# 4       Switch  Apr 26, 1965  1.35       30%   3.55       38%    1.07     33%
# ...        ...           ...   ...       ...    ...       ...     ...     ...
# 4447                      --  0.00        0%   0.00        0%    0.00      0%
# 4448                      --  7.64       38%   5.45       37%    0.00      0%
# 4449  Orthodox  Apr 04, 1992  3.93       52%   1.80       61%    0.00      0%
# 4450  Orthodox  Mar 10, 1996  1.86       15%   5.57       59%    0.00      0%
# 4451            Jun 26, 1982  3.34       48%   4.87       39%    1.31     30%
#
#      TD Def. Sub. Avg.
# 0         0%       0.0
# 1        77%       0.0
# 2        66%       0.0
# 3         0%       0.0
# 4        66%       0.0
# ...      ...       ...
# 4447      0%       0.0
# 4448    100%       0.0
# 4449     57%       1.0
# 4450      0%       0.0
# 4451     50%       0.0
#
# [4452 rows x 16 columns]
# Archivo CSV 'all_fighters.csv' creado.

# %% [markdown]
# **Ejercicio extra 3** Extrae todas las peleas del evento UFC 308 con sus detalles y haz un dataframe `ufc308.csv`
