# %% [markdown]
# <h3>0. Dada una cadena que contiene una frase, determina si es un palíndromo (si los espacios en blanco no son relevantes).</h3> Un palíndromo se lee igual de adelante hacia atrás que de atrás hacia adelante.

# %%
data = 'dabale arroz a la zorra el abad'

print('Is it palindrome?', is_palindrome)
# Out:
# Is it palindrome? True

# %% [markdown]
# <h3>1. Dada una cadena que contiene un código binario, encuentra la longitud de la
# secuencia más larga de unos consecutivos.</h3>
# <h4>1.1 Indica la posición donde comienza la
# secuencia más larga de unos consecutivos en la cadena dada.</h4>

# %%
data = '1001010101111101010101010111100101010011111110001001110010'

print('The longest burst of ones has length:', max_burst_len) # should print 7
print('was found at position:', max_burst_index)) # should print 38

# %% [markdown]
# <h3>2. Dada una cadena de letras, intercambia las dos primeras letras <u>si no están en orden alfabético</u></h3>
# <h4>2.1 Haz lo mismo para todos los pares de letras consecutivas en la cadena</h4>
# <h4>2.2 Repite este proceso hasta que toda la cadena esté ordenada alfabéticamente</h4>

# %%
data = 'abzefyhijklmnuoptq'

print(new_data)

# %% [markdown]
# <h3>3. Dada una cadena de números enteros separados por comas, calcula la media</h3>
# <h4>3.1 Pon especial atención en identificar correctamente los números enteros</h4>

# %%
data = '100,-200,100,40' 

print('The average is:', average)) # should print 10

# %% [markdown]
# <h3>4. Dada una cadena con algunas palabras separadas por espacios, genera una cadena similar pero sin palabras repetidas.</h3>

# %%
data = 'their father followed their track for many many hours until the sunset'

print(result) # their father followed track for many hours until the sunset

# %% [markdown]
# <h3>5. Dado un archivo de texto, contar la aparición de cada palabra.</h3>
# <h4>5.1 Leer el contenido del archivo y procesarlo para identificar las palabras.</h4>
# <h4>5.2 Ignorar mayúsculas y signos de puntuación para considerar palabras equivalentes.</h4>
# <h4>5.3 Generar un diccionario donde las claves sean las palabras y los valores el número de veces que aparecen en el texto.</h4>
# <h4>5.4 Mostrar las palabras ordenadas de mayor a menor frecuencia de aparición.</h4>

# %%
import string
from collections import Counter

def contar_palabras(archivo):
    """
    Lee un archivo de texto y cuenta la aparición de cada palabra.
    """
    frecuencia_palabras ={}
    try:
        with open(archivo, "r", encoding="utf-8") as f:
            texto = f.read().lower()  # Convertir todo a minúsculas para evitar duplicados
        
        # Eliminar puntuación
        texto = texto.translate(str.maketrans("", "", string.punctuation))
        
        # Dividir en palabras
        palabras = texto.split()
        
        # Contar ocurrencias
        frecuencia_palabras = {}

        # Aqui completa tu código ...
        
    except FileNotFoundError:
        print("Error: El archivo no existe.")
    except Exception as e:
        print(f"Ocurrió un error: {e}")

    return frecuencia_palabras

def imprimirDiccionario(frecuencia_palabras):
    # Mostrar resultados ordenados por frecuencia
    for palabra, frecuencia in frecuencia_palabras.most_common():
        print(f"{palabra}: {frecuencia}")
        
# Ejemplo de uso
archivo = "texto_test.txt"  # Nombre del archivo de texto
#archivo = "texto_cars.txt"  # Nombre del archivo de texto
#archivo = "texto_ibai.txt"  # Nombre del archivo de texto
freq = contar_palabras(archivo)
imprimirDiccionario(freq)
# Out:
# este: 4
# de: 4
# texto: 4
# palabras: 4
# repetidas: 4
# es: 2
# un: 2
# ejemplo: 2
# archivo: 2
# tiene: 2
# las: 2
# ayudan: 2
# a: 2
# probar: 2
# el: 2
# código: 2
# correctamente: 2

# %% [markdown]
# <h3>Prueba experimental.
#
# En el texto anterior, vemos que no podemos sacar mucha información porque sobre todo se repiten conjunciones, determinantes etc. Si te ha sobrado tiempo haciendo los ejercicios, vamos a jugar un rato 😈.</h3>
#
# Ahora vamos a probar a instalar una librería para analizar el lenguaje. Ejecuta el siguiente bloque para instalar spacy y su modelo de lenguaje.

# %%
import subprocess
import sys

def instalar_spacy_y_modelo():
    try:
        import spacy
        print("spaCy ya está instalado.")
    except ImportError:
        print("spaCy no está instalado. Instalando...")
        subprocess.check_call([sys.executable, "-m", "pip", "install", "spacy"])
        print("spaCy instalado correctamente.")

    # Intentar cargar el modelo de español
    try:
        import spacy
        spacy.load("es_core_news_sm")
        print("El modelo 'es_core_news_sm' ya está instalado.")
    except OSError:
        print("El modelo 'es_core_news_sm' no está instalado. Instalando...")
        subprocess.check_call([sys.executable, "-m", "spacy", "download", "es_core_news_sm"])
        print("Modelo 'es_core_news_sm' instalado correctamente.")

        # Verificar instalación nuevamente
        try:
            spacy.load("es_core_news_sm")
            print("Verificación completa: spaCy y el modelo en español están listos.")
        except OSError:
            print("Error: El modelo no pudo ser cargado después de la instalación.")

# Ejecutar la instalación
instalar_spacy_y_modelo()
# Out:
# spaCy ya está instalado.
# El modelo 'es_core_news_sm' no está instalado. Instalando...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 13.0 MB/s eta 0:00:0000:0100:01
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')
# Modelo 'es_core_news_sm' instalado correctamente.
# Verificación completa: spaCy y el modelo en español están listos.

# %% [markdown]
# <h3>Ahora ya debería estar instalado, vamos a ver que funciona ...</h3>

# %%
import spacy

# Cargar el modelo en español de spaCy
nlp = spacy.load("es_core_news_sm")

def es_verbo(palabra):
    doc = nlp(palabra)
    return any(token.pos_ == "VERB" for token in doc)

def es_sustantivo(palabra):
    """
    Analiza si una palabra es un sustantivo común.
    """
    doc = nlp(palabra)
    return any(token.pos_ == "NOUN" for token in doc)  # "NOUN" indica sustantivos comunes

# Ejemplo
print("Starting...")
palabras = ["correr", "rápido", "jugando", "feliz", "comer", "perro"]
verbos = [palabra for palabra in palabras if es_verbo(palabra)]
sustantivos = [palabra for palabra in palabras if es_sustantivo(palabra)]
print("Verbos encontrados:", verbos)
print("Sustantivos encontrados:", sustantivos)
# Out:
# Starting...
# Verbos encontrados: ['correr', 'jugando', 'comer']
# Sustantivos encontrados: ['perro']

# %% [markdown]
# <h3>Si encuentra los verbos y sustantivos, ahora vuelve a analizar el texto de Ibai, y analiza cuales son los verbos y sustantivos más utilizados </h3>

# %%
def contar_verbos_y_nombres(archivo_entrada):
   

archivo = "texto_ibai.txt"  # Nombre del archivo de texto
#archivo = "texto_cars.txt"  # Nombre del archivo de texto
#archivo = "texto_ibai.txt"  # Nombre del archivo de texto
contar_verbos_y_nombres(archivo)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[91], line 43
#      40 archivo = "texto_ibai.txt"  # Nombre del archivo de texto
#      41 #archivo = "texto_cars.txt"  # Nombre del archivo de texto
#      42 #archivo = "texto_ibai.txt"  # Nombre del archivo de texto
# ---> 43 contar_verbos_y_nombres(archivo)
#
# Cell In[91], line 22, in contar_verbos_y_nombres(archivo_entrada)
#      20 # Iterar sobre cada palabra y contar solo sustantivos y verbos
#      21 for token in palabras:
# ---> 22     if es_sustantivo(token) or es_verbo(token):
#      23         palabra = token
#      24         # Comprobar si la palabra ya está en el diccionario
#
# Cell In[55], line 14, in es_sustantivo(palabra)
#      10 def es_sustantivo(palabra):
#      11     """
#      12     Analiza si una palabra es un sustantivo común.
#      13     """
# ---> 14     doc = nlp(palabra)
# ...
