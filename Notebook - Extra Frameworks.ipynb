# %% [markdown]
# ## *1*. Crea una funcion que reciba una cadena de texto y una lista de palabras, contando cuántas veces aparece la palabras dentro de la lista.

# %%
import numpy as np
def count_elements(text, list):
    arrayLista = np.array(list)

print(count_elements("hello", ["hello", "world"]))
# Out:
#   Cell In[1], line 4
#     print(count_elements("hello", ["hello", "world"]))
#     ^
# IndentationError: expected an indented block after function definition on line 1

# %% [markdown]
# # 2. En este ejercicio buscamos procesar cadenas de texto.
# ### La siguiente cadena muestra un formato en el que se reciben bloques de tres líneas, la primera línea representa el identificador de bloque, la segunda la fecha de inicio y la fecha final de un evento, y el tercero el identificador del evento.
#
# ```python
# 1
# 00:00:00,199 --> 00:00:01,680
# Texto inicial
#
# 2
# 00:00:01,680 --> 00:00:03,240
# Texto secundario
# ```
#
# ### Crea una funcion que reciba una lista de cadenas de texto (puedes suponer que no hay errores). Y devuelve tres listas: una lista de los inicios de los eventos, otra lista de los finales de los eventos y otra lista con el texto final.
#
# Debes llamarlas start_times, end_times y text_lines.

# %%
def process_lines(lines):
    # solucion
    
    return start_times, end_times, text_lines

# Ejemplo de entrada
events = [
    "1",
    "00:00:00,199 --> 00:00:01,680",
    "Texto inicial",
    "2",
    "00:00:01,680 --> 00:00:03,240",
    "Texto secundario"
]

# Llamar a la función y mostrar los resultados
start_times, end_times, text_lines = process_lines(events)
print("Start Times:", start_times)
print("End Times:", end_times)
print("Text Lines:", text_lines)
# Out:
# Start Times: ['00:00:00,199', '00:00:01,680']
# End Times: ['00:00:01,680', '00:00:03,240']
# Text Lines: ['Texto inicial', 'Texto secundario']

# %% [markdown]
# ## 3. Turno de crear dataframes
#
# Con las estructuras de datos ya procesadas, vamos a crear un DataFrame con las columnas: start_time, end_times y text. Convierte las dos primeras columnas en fechas.

# %% [markdown]
# ## 4. Añadir columna duración
#
# Para añadir informacion extra al DataFrame, se ha decidido incluir una columna *duration*, que incluya la duración de cada fila. Esta duración se calcula operando las columnas start_time y end_times. Para ello, crea una funcion *def calculate_duration(row)* que reciba una fila y calcule la duracion total de la misma.
#
# PD: Pista, para convertir de texto a 'datetime' se utiliza la funcion *datetime.strptime*.
